# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
Created on 2024-05-27

@author: Juan Enrique López

@description: Jupyter Notebook creado para obtener las vulnerabilidades publicadas en NIST en los últimos n días.

"""
# Out:
# '\nCreated on 2024-05-27\n\n@author: Juan Enrique López\n\n@description: Jupyter Notebook creado para obtener las vulnerabilidades publicadas en NIST en los últimos n días.\n\n'

# %% [markdown]
# #### NIST

# %% [markdown]
# **Requerimientos**

# %%
import nvdlib
import datetime
import os

# %% [markdown]
# **Parámetros**

# %%
# save_as_md = True
# end_date = datetime.datetime.now()
# start_date = end_date - datetime.timedelta(days=1)
test_start_date = '06/02/2023'
test_start_date = datetime.datetime.strptime(test_start_date, '%d/%m/%Y')
test_start_date
test_end_date = test_start_date+ datetime.timedelta(days=1)
test_end_date
# Out:
# datetime.datetime(2023, 2, 7, 0, 0)

# %% [markdown]
# **Funciones**

# %%
# OLD CODE: JUST CVSS 3.1
'''
def create_header_properties(cve):
    vectorString = version = impactScore = exploitabilityScore = attackVector = attackComplexity = privilegesRequired = userInteraction = scope = confidentialityImpact = integrityImpact = availabilityImpact = source = ''
    if hasattr(cve, 'metrics'):
        if len(cve.metrics)>=1:
            if hasattr(cve.metrics, 'cvssMetricV31'):
                vectorString = cve.metrics.cvssMetricV31[0].cvssData.vectorString
                version = cve.metrics.cvssMetricV31[0].cvssData.version
                impactScore = cve.metrics.cvssMetricV31[0].impactScore
                exploitabilityScore = cve.metrics.cvssMetricV31[0].exploitabilityScore
                attackVector = cve.metrics.cvssMetricV31[0].cvssData.attackVector
                attackComplexity = cve.metrics.cvssMetricV31[0].cvssData.attackComplexity
                privilegesRequired = cve.metrics.cvssMetricV31[0].cvssData.privilegesRequired
                userInteraction = cve.metrics.cvssMetricV31[0].cvssData.userInteraction
                scope = cve.metrics.cvssMetricV31[0].cvssData.scope
                confidentialityImpact = cve.metrics.cvssMetricV31[0].cvssData.confidentialityImpact
                integrityImpact = cve.metrics.cvssMetricV31[0].cvssData.integrityImpact
                availabilityImpact = cve.metrics.cvssMetricV31[0].cvssData.availabilityImpact
                source = cve.metrics.cvssMetricV31[0].source
        
    header = f"""---
CP Source: "NIST"
CP Execution date: {'"'+str(datetime.datetime.now().strftime('%Y-%m-%d'))+'"'}
Vulnerability ID: {'"'+str(cve.id)+'"'}
Date: {'"'+str(datetime.datetime.strptime(cve.published, '%Y-%m-%dT%H:%M:%S.%f').strftime('%Y-%m-%d'))+'"'}
Base Score: {'"'+str(cve.score[1])} {str(cve.score[2])+'"'}
Vector: {'"'+str(vectorString)+'"'}
Version: {'"'+str(version)+'"'}
Impact Score: {'"'+str(impactScore)+'"'}
Exploitability Score: {'"'+str(exploitabilityScore)+'"'}
Attack Vector (AV): {'"'+str(attackVector)+'"'}
Attack Complexity (AC): {'"'+str(attackComplexity)+'"'}
Privileges Required (PR): {'"'+str(privilegesRequired)+'"'}
User Interaction (UI): {'"'+str(userInteraction)+'"'}
Scope (S): {'"'+str(scope)+'"'}
Confidentiality (C): {'"'+str(confidentialityImpact)+'"'}
Integrity (I): {'"'+str(integrityImpact)+'"'}
Availability (A): {'"'+str(availabilityImpact)+'"'}
Source: {'"'+str(source)+'"'}
---
"""
    
    return header

'''

# %%
id_busqueda = 'CVE-2023-0687'
v = [cve for cve in vulnerabilities if cve.id == id_busqueda]
v = v[0]
type(v)
# Out:
# nvdlib.classes.CVE

# %%
v.metrics.cvssMetricV31[0].source
# Out:
# 'nvd@nist.gov'

# %%
if v.metrics.cvssMetricV31[0].source == 'nvd@nist.gov':
    print('hola')
# Out:
# hola

# %%
len(v.metrics.cvssMetricV31)
# Out:
# 1

# %%
def create_header_properties(cve):
    cvss31_baseScore = cvss31_baseSeverity = cvss31_vectorString = cvss31_version = cvss31_impactScore = cvss31_exploitabilityScore = cvss31_attackVector = cvss31_attackComplexity = cvss31_privilegesRequired = cvss31_userInteraction = cvss31_scope = cvss31_confidentialityImpact = cvss31_integrityImpact = cvss31_availabilityImpact = cvss31_source = ''

    cna_baseScore = cna_baseSeverity = cna_vectorString = cna_version = cna_impactScore = cna_exploitabilityScore = cna_attackVector = cna_attackComplexity = cna_privilegesRequired = cna_userInteraction = cna_scope = cna_confidentialityImpact = cna_integrityImpact = cna_availabilityImpact = cna_source = ''


    if hasattr(cve, 'metrics'):
        if len(cve.metrics)>=1:
            if hasattr(cve.metrics, 'cvssMetricV31'):
                # Mapeamos las variavles 
                if cve.metrics.cvssMetricV31[0].source == 'nvd@nist.gov':
                    cvss31_baseScore =  cve.metrics.cvssMetricV31[0].cvssData.baseScore
                    cvss31_baseSeverity = cve.metrics.cvssMetricV31[0].cvssData.baseSeverity
                    cvss31_vectorString = cve.metrics.cvssMetricV31[0].cvssData.vectorString
                    cvss31_version = cve.metrics.cvssMetricV31[0].cvssData.version
                    cvss31_impactScore = cve.metrics.cvssMetricV31[0].impactScore
                    cvss31_exploitabilityScore = cve.metrics.cvssMetricV31[0].exploitabilityScore
                    cvss31_attackVector = cve.metrics.cvssMetricV31[0].cvssData.attackVector
                    cvss31_attackComplexity = cve.metrics.cvssMetricV31[0].cvssData.attackComplexity
                    cvss31_privilegesRequired = cve.metrics.cvssMetricV31[0].cvssData.privilegesRequired
                    cvss31_userInteraction = cve.metrics.cvssMetricV31[0].cvssData.userInteraction
                    cvss31_scope = cve.metrics.cvssMetricV31[0].cvssData.scope
                    cvss31_confidentialityImpact = cve.metrics.cvssMetricV31[0].cvssData.confidentialityImpact
                    cvss31_integrityImpact = cve.metrics.cvssMetricV31[0].cvssData.integrityImpact
                    cvss31_availabilityImpact = cve.metrics.cvssMetricV31[0].cvssData.availabilityImpact
                    cvss31_source = cve.metrics.cvssMetricV31[0].source
                # Mapeamos variables CNA
                if len(cve.metrics.cvssMetricV31)==2 and cve.metrics.cvssMetricV31[1].source == 'cna@vuldb.com':
                    cna_baseScore =  cve.metrics.cvssMetricV31[1].cvssData.baseScore
                    cna_baseSeverity = cve.metrics.cvssMetricV31[1].cvssData.baseSeverity
                    cna_vectorString = cve.metrics.cvssMetricV31[1].cvssData.vectorString
                    cna_version = cve.metrics.cvssMetricV31[1].cvssData.version
                    cna_impactScore = cve.metrics.cvssMetricV31[1].impactScore
                    cna_exploitabilityScore = cve.metrics.cvssMetricV31[1].exploitabilityScore
                    cna_attackVector = cve.metrics.cvssMetricV31[1].cvssData.attackVector
                    cna_attackComplexity = cve.metrics.cvssMetricV31[1].cvssData.attackComplexity
                    cna_privilegesRequired = cve.metrics.cvssMetricV31[1].cvssData.privilegesRequired
                    cna_userInteraction = cve.metrics.cvssMetricV31[1].cvssData.userInteraction
                    cna_scope = cve.metrics.cvssMetricV31[1].cvssData.scope
                    cna_confidentialityImpact = cve.metrics.cvssMetricV31[1].cvssData.confidentialityImpact
                    cna_integrityImpact = cve.metrics.cvssMetricV31[1].cvssData.integrityImpact
                    cna_availabilityImpact = cve.metrics.cvssMetricV31[1].cvssData.availabilityImpact
                    cna_source = cve.metrics.cvssMetricV31[1].source



    header = f"""---
CP Source: "NIST"
CP Execution date: {'"'+str(datetime.datetime.now().strftime('%Y-%m-%d'))+'"'}
Vulnerability ID: {'"'+str(cve.id)+'"'}
Date: {'"'+str(datetime.datetime.strptime(cve.published, '%Y-%m-%dT%H:%M:%S.%f').strftime('%Y-%m-%d'))+'"'}
CVSS 3.x Base Score: {'"'+str(cvss31_baseScore)} {str(cvss31_baseSeverity)+'"'}
CVSS 3.x Vector: {'"'+str(cvss31_vectorString)+'"'}
CVSS 3.x Version: {'"'+str(cvss31_version)+'"'}
CVSS 3.x Impact Score: {'"'+str(cvss31_exploitabilityScore)+'"'}
CVSS 3.x Exploitability Score: {'"'+str(cvss31_exploitabilityScore)+'"'}
CVSS 3.x Attack Vector (AV): {'"'+str(cvss31_attackVector)+'"'}
CVSS 3.x Attack Complexity (AC): {'"'+str(cvss31_attackComplexity)+'"'}
CVSS 3.x Privileges Required (PR): {'"'+str(cvss31_privilegesRequired)+'"'}
CVSS 3.x User Interaction (UI): {'"'+str(cvss31_userInteraction)+'"'}
CVSS 3.x Scope (S): {'"'+str(cvss31_scope)+'"'}
CVSS 3.x Confidentiality (C): {'"'+str(cvss31_confidentialityImpact)+'"'}
CVSS 3.x Integrity (I): {'"'+str(cvss31_integrityImpact)+'"'}
CVSS 3.x Availability (A): {'"'+str(cvss31_availabilityImpact)+'"'}
CVSS 3.x Source: {'"'+str(cvss31_source)+'"'}

CNA Base Score: {'"'+str(cna_baseSeverity)} {str(cna_baseScore)+'"'}
CNA Vector: {'"'+str(cna_vectorString)+'"'}
CNA Version: {'"'+str(cna_version)+'"'}
CNA Impact Score: {'"'+str(cna_exploitabilityScore)+'"'}
CNA Exploitability Score: {'"'+str(cna_exploitabilityScore)+'"'}
CNA Attack Vector (AV): {'"'+str(cna_attackVector)+'"'}
CNA Attack Complexity (AC): {'"'+str(cna_attackComplexity)+'"'}
CNA Privileges Required (PR): {'"'+str(cna_privilegesRequired)+'"'}
CNA User Interaction (UI): {'"'+str(cna_userInteraction)+'"'}
CNA Scope (S): {'"'+str(cna_scope)+'"'}
CNA Confidentiality (C): {'"'+str(cna_confidentialityImpact)+'"'}
CNA Integrity (I): {'"'+str(cna_integrityImpact)+'"'}
CNA Availability (A): {'"'+str(cna_availabilityImpact)+'"'}
CNA Source: {'"'+str(cna_source)+'"'}


---
"""
    
    return header

# %%
def write_dict_to_md(cve, write_name):
    try:
        with open(write_name, 'w', encoding='utf-8') as file:
            v_dict = cve.__dict__
            header_properties = create_header_properties(cve)
            file.write(header_properties+ "\n")
            # Forma simple de escritura del contenido:
            # for key, value in v_dict.items():
            #     value = str(value).replace('[', '').replace(']', '')
            #     file.write(f"{key}\n{value}\n\n")
            file.write('**'+'Vulnerability ID' + '**' + "\n")
            file.write(cve.id+ "\n")
            file.write("\n"+'**'+'Description' + '**' + "\n")
            file.write(cve.descriptions[0].value + "\n") # Ojo, chequear items sin descripción
            file.write("\n"+'**'+'References to Advisories, Solutions, and Tools'+'**'+ "\n")
            if len(cve.references)>0:
                for r in range(len(cve.references)):
                    file.write(cve.references[r].source +' - '+cve.references[r].url+ "\n")
            file.write("\n"+ '**' + 'Weakness Enumeration'+'**'+ "\n")
            if hasattr(cve, 'weaknesses'):
                if len(cve.weaknesses) > 0:
                    for w in range(len(cve.weaknesses)):
                        file.write(cve.weaknesses[0].description[0].value +' - '+ 'https://cwe.mitre.org/data/definitions/'+cve.weaknesses[0].description[0].value[4:]+'.html')
        print(f"Archivo .md guardado en: {write_name}")
    except (OSError, IOError) as e:
        print(f"Error al escribir en el archivo {write_name}: {e}")

# %%
def get_nist_vulnerabilities(s_date, e_date):
    results = nvdlib.searchCVE(pubStartDate=s_date, pubEndDate=e_date)
    return results

# %% [markdown]
# **Ejecución principal**

# %%
# vulnerabilities = get_nist_vulnerabilities(start_date, end_date)
# print(f"Se han obtenido {str(len(vulnerabilities))} vulnerabilidades entre las fechas {start_date.strftime('%d/%m/%Y')} y {end_date.strftime('%d/%m/%Y')}")
vulnerabilities = get_nist_vulnerabilities(test_start_date, test_end_date)
print(f"Se han obtenido {str(len(vulnerabilities))} vulnerabilidades entre las fechas {test_start_date.strftime('%d/%m/%Y')} y {test_end_date.strftime('%d/%m/%Y')}")
# Out:
# Se han obtenido 137 vulnerabilidades entre las fechas 06/02/2023 y 07/02/2023

# %% [markdown]
# El objetivo es: guardar un .md por cada vulnerabilidad en una carpeta que lleve por nombre la fecha de la publicación.
#
# El nombre del md generado sera conformado por el id de la vulnerabilidad + la fecha y hora de publicación.

# %%
# Recorremos el listado de vulnerabilidades
for v in vulnerabilities:
    # Chequeamos que la fecha de publicación para el guardado y asignamos nombre del fichero final
    if v.published != '':
        folder_name = os.path.join(os.getcwd(), 'outputs', 'NIST', 'save_by_date', datetime.datetime.strptime(v.published, '%Y-%m-%dT%H:%M:%S.%f').strftime('%Y%m%d'))
        # file_name = v.id +'_'+ datetime.datetime.strptime(v.published, '%Y-%m-%dT%H:%M:%S.%f').strftime('%Y%m%d_%H%M')+'h.md' #temporal
        file_name = v.id + '_' + datetime.datetime.strptime(v.published, '%Y-%m-%dT%H:%M:%S.%f').strftime('%Y%m%d_%H%Mh') +'.md' 
    else:
        folder_name = os.path.join(os.getcwd(), 'outputs', 'NIST', 'save_by_date', 'no-pubish-date')
        file_name =   v.id + '_' + 'no-pubish-date'+'.md'
    # Creamos carpeta si no existe
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    # Controlamos el guardado de los archivos mediante un parámetro
    if save_as_md:
        write_name = os.path.join(folder_name, file_name)
        write_dict_to_md(v, write_name)
# Out:
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2014-125084_20230206_0015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2014-125085_20230206_0015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2014-125086_20230206_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2017-20176_20230206_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-25853_20230206_0515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-25855_20230206_0515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-27628_20230206_1315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-29416_20230206_1315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-45722_20230206_1315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0679_20230206_1315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2021-36224_20230206_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2021-36225_20230206_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2021-36226_20230206_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-44343_20230206_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-48085_20230206_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-48164_20230206_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-48019_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-24191_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-24192_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-24194_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-24195_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-24197_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-24198_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-24199_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-24200_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-24201_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-24202_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-24276_20230206_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-48078_20230206_1615h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2020-36660_20230206_1715h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-47071_20230206_1715h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-2933_20230206_1915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-38136_20230206_1915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-40196_20230206_1915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-41342_20230206_1915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4902_20230206_1915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0687_20230206_1915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2015-10073_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2017-20177_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-32595_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-32642_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-32643_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-32654_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-32655_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-32656_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-32663_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4321_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4384_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4459_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4489_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4577_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4626_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4657_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4664_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4670_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4674_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4677_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4681_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4717_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4747_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4756_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4762_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4824_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4825_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4826_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4833_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4836_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-4838_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0062_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0070_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0072_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0081_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0082_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0095_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0096_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0143_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0144_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0146_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0147_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0148_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0149_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0150_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0153_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0154_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0170_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0171_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0173_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0174_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0176_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0178_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0234_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0236_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0252_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0282_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0669_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0686_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20602_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20604_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20605_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20606_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20607_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20608_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20609_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20610_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20611_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20612_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20613_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20614_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20615_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20616_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20618_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-20619_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-23944_20230206_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-42439_20230206_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-42950_20230206_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-42951_20230206_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-44267_20230206_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-44268_20230206_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-45589_20230206_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-48311_20230206_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-23942_20230206_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-23943_20230206_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-25016_20230206_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2021-31573_20230206_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2021-31574_20230206_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2021-31575_20230206_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2021-31576_20230206_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2021-31577_20230206_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2021-31578_20230206_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-48166_20230206_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-23333_20230206_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-28923_20230206_2315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-3229_20230206_2315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-44617_20230206_2315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2022-46496_20230206_2315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-0615_20230206_2315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\web_scraping\outputs\NIST\save_by_date\20230206\CVE-2023-23849_20230206_2315h.md

# %%
# Out:
# 'aaNone'
