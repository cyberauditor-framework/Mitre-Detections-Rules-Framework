# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
Created on 2024-05-27

@author: Juan Enrique López

@description: Jupyter Notebook creado para obtener las vulnerabilidades publicadas en NIST en los últimos n días.

"""
# Out:
# '\nCreated on 2024-05-27\n\n@author: Juan Enrique López\n\n@description: Jupyter Notebook creado para obtener las vulnerabilidades publicadas en NIST en los últimos n días.\n\n'

# %% [markdown]
# #### **NIST**

# %% [markdown]
# **Requerimientos**

# %%
import nvdlib
import datetime
import os

# %% [markdown]
# **Parámetros**

# %%
save_as_md = True
end_date = datetime.datetime.now()
start_date = end_date - datetime.timedelta(days=1)

# %% [markdown]
# **Funciones**

# %%
# Función encargada de construir las propiedades del fichero .md
def create_header_properties(cve):
    cvss31_baseScore = cvss31_baseSeverity = cvss31_vectorString = cvss31_version = cvss31_impactScore = cvss31_exploitabilityScore = cvss31_attackVector = cvss31_attackComplexity = cvss31_privilegesRequired = cvss31_userInteraction = cvss31_scope = cvss31_confidentialityImpact = cvss31_integrityImpact = cvss31_availabilityImpact = cvss31_source = ''

    cna_baseScore = cna_baseSeverity = cna_vectorString = cna_version = cna_impactScore = cna_exploitabilityScore = cna_attackVector = cna_attackComplexity = cna_privilegesRequired = cna_userInteraction = cna_scope = cna_confidentialityImpact = cna_integrityImpact = cna_availabilityImpact = cna_source = ''

    cvss20_baseScore = cvss20_baseSeverity = cvss20_vectorString = cvss20_impactSubscore = cvss20_exploitabilitySubscore = cvss20_accessVector = cvss20_accessComplexity = cvss20_authentication = cvss20_confidentialityImpact = cvss20_integrityImpact = cvss20_availabilityImpact = ''

    if hasattr(cve, 'metrics'):
        if len(cve.metrics)>=1:
            if hasattr(cve.metrics, 'cvssMetricV31'):
                # Mapeamos las variavles 
                if cve.metrics.cvssMetricV31[0].source == 'nvd@nist.gov':
                    cvss31_baseScore =  cve.metrics.cvssMetricV31[0].cvssData.baseScore
                    cvss31_baseSeverity = cve.metrics.cvssMetricV31[0].cvssData.baseSeverity
                    cvss31_vectorString = cve.metrics.cvssMetricV31[0].cvssData.vectorString
                    cvss31_version = cve.metrics.cvssMetricV31[0].cvssData.version
                    cvss31_impactScore = cve.metrics.cvssMetricV31[0].impactScore
                    cvss31_exploitabilityScore = cve.metrics.cvssMetricV31[0].exploitabilityScore
                    cvss31_attackVector = cve.metrics.cvssMetricV31[0].cvssData.attackVector
                    cvss31_attackComplexity = cve.metrics.cvssMetricV31[0].cvssData.attackComplexity
                    cvss31_privilegesRequired = cve.metrics.cvssMetricV31[0].cvssData.privilegesRequired
                    cvss31_userInteraction = cve.metrics.cvssMetricV31[0].cvssData.userInteraction
                    cvss31_scope = cve.metrics.cvssMetricV31[0].cvssData.scope
                    cvss31_confidentialityImpact = cve.metrics.cvssMetricV31[0].cvssData.confidentialityImpact
                    cvss31_integrityImpact = cve.metrics.cvssMetricV31[0].cvssData.integrityImpact
                    cvss31_availabilityImpact = cve.metrics.cvssMetricV31[0].cvssData.availabilityImpact
                    cvss31_source = cve.metrics.cvssMetricV31[0].source
                # Mapeamos variables CNA
                if len(cve.metrics.cvssMetricV31)==2 and cve.metrics.cvssMetricV31[1].source == 'cna@vuldb.com':
                    cna_baseScore =  cve.metrics.cvssMetricV31[1].cvssData.baseScore
                    cna_baseSeverity = cve.metrics.cvssMetricV31[1].cvssData.baseSeverity
                    cna_vectorString = cve.metrics.cvssMetricV31[1].cvssData.vectorString
                    cna_version = cve.metrics.cvssMetricV31[1].cvssData.version
                    cna_impactScore = cve.metrics.cvssMetricV31[1].impactScore
                    cna_exploitabilityScore = cve.metrics.cvssMetricV31[1].exploitabilityScore
                    cna_attackVector = cve.metrics.cvssMetricV31[1].cvssData.attackVector
                    cna_attackComplexity = cve.metrics.cvssMetricV31[1].cvssData.attackComplexity
                    cna_privilegesRequired = cve.metrics.cvssMetricV31[1].cvssData.privilegesRequired
                    cna_userInteraction = cve.metrics.cvssMetricV31[1].cvssData.userInteraction
                    cna_scope = cve.metrics.cvssMetricV31[1].cvssData.scope
                    cna_confidentialityImpact = cve.metrics.cvssMetricV31[1].cvssData.confidentialityImpact
                    cna_integrityImpact = cve.metrics.cvssMetricV31[1].cvssData.integrityImpact
                    cna_availabilityImpact = cve.metrics.cvssMetricV31[1].cvssData.availabilityImpact
                    cna_source = cve.metrics.cvssMetricV31[1].source

            if hasattr(cve.metrics, 'cvssMetricV2'):
                    cvss20_baseScore =  cve.metrics.cvssMetricV2[0].cvssData.baseScore
                    cvss20_baseSeverity = cve.metrics.cvssMetricV2[0].baseSeverity
                    cvss20_vectorString = cve.metrics.cvssMetricV2[0].cvssData.vectorString
                    cvss20_impactSubscore = cve.metrics.cvssMetricV2[0].impactScore
                    cvss20_exploitabilitySubscore = cve.metrics.cvssMetricV2[0].exploitabilityScore
                    cvss20_accessVector = cve.metrics.cvssMetricV2[0].cvssData.accessVector
                    cvss20_accessComplexity = cve.metrics.cvssMetricV2[0].cvssData.accessComplexity
                    cvss20_authentication = cve.metrics.cvssMetricV2[0].cvssData.authentication
                    cvss20_confidentialityImpact = cve.metrics.cvssMetricV2[0].cvssData.confidentialityImpact
                    cvss20_integrityImpact = cve.metrics.cvssMetricV2[0].cvssData.integrityImpact
                    cvss20_availabilityImpact = cve.metrics.cvssMetricV2[0].cvssData.availabilityImpact

    header = f"""---
CP Source: "NIST"
CP Execution date: {'"'+str(datetime.datetime.now().strftime('%Y-%m-%d'))+'"'}
Vulnerability ID: {'"'+str(cve.id)+'"'}
Date: {'"'+str(datetime.datetime.strptime(cve.published, '%Y-%m-%dT%H:%M:%S.%f').strftime('%Y-%m-%d'))+'"'}
CVSS 3.x Base Score: {'"'+str(cvss31_baseScore)} {str(cvss31_baseSeverity)+'"'}
CVSS 3.x Vector: {'"'+str(cvss31_vectorString)+'"'}
CVSS 3.x Version: {'"'+str(cvss31_version)+'"'}
CVSS 3.x Impact Score: {'"'+str(cvss31_exploitabilityScore)+'"'}
CVSS 3.x Exploitability Score: {'"'+str(cvss31_exploitabilityScore)+'"'}
CVSS 3.x Attack Vector (AV): {'"'+str(cvss31_attackVector)+'"'}
CVSS 3.x Attack Complexity (AC): {'"'+str(cvss31_attackComplexity)+'"'}
CVSS 3.x Privileges Required (PR): {'"'+str(cvss31_privilegesRequired)+'"'}
CVSS 3.x User Interaction (UI): {'"'+str(cvss31_userInteraction)+'"'}
CVSS 3.x Scope (S): {'"'+str(cvss31_scope)+'"'}
CVSS 3.x Confidentiality (C): {'"'+str(cvss31_confidentialityImpact)+'"'}
CVSS 3.x Integrity (I): {'"'+str(cvss31_integrityImpact)+'"'}
CVSS 3.x Availability (A): {'"'+str(cvss31_availabilityImpact)+'"'}
CVSS 3.x Source: {'"'+str(cvss31_source)+'"'}

CNA Base Score: {'"'+str(cna_baseSeverity)} {str(cna_baseScore)+'"'}
CNA Vector: {'"'+str(cna_vectorString)+'"'}
CNA Version: {'"'+str(cna_version)+'"'}
CNA Impact Score: {'"'+str(cna_exploitabilityScore)+'"'}
CNA Exploitability Score: {'"'+str(cna_exploitabilityScore)+'"'}
CNA Attack Vector (AV): {'"'+str(cna_attackVector)+'"'}
CNA Attack Complexity (AC): {'"'+str(cna_attackComplexity)+'"'}
CNA Privileges Required (PR): {'"'+str(cna_privilegesRequired)+'"'}
CNA User Interaction (UI): {'"'+str(cna_userInteraction)+'"'}
CNA Scope (S): {'"'+str(cna_scope)+'"'}
CNA Confidentiality (C): {'"'+str(cna_confidentialityImpact)+'"'}
CNA Integrity (I): {'"'+str(cna_integrityImpact)+'"'}
CNA Availability (A): {'"'+str(cna_availabilityImpact)+'"'}
CNA Source: {'"'+str(cna_source)+'"'}

CVSS 2.x Base Score: {'"'+str(cvss20_baseScore)} {str(cvss20_baseSeverity)+'"'}
CVSS 2.x Vector: {'"'+str(cvss20_vectorString)+'"'}
CVSS 2.x Impact Subscore: {'"'+str(cvss20_impactSubscore)+'"'}
CVSS 2.x Exploitability Subscore: {'"'+str(cvss20_exploitabilitySubscore)+'"'}
CVSS 2.x Access Vector (AV): {'"'+str(cvss20_accessVector)+'"'}
CVSS 2.x Access Complexity (AC): {'"'+str(cvss20_accessComplexity)+'"'}
CVSS 2.x Authentication (AU): {'"'+str(cvss20_authentication)+'"'}
CVSS 2.x Confidentiality (C): {'"'+str(cvss20_confidentialityImpact)+'"'}
CVSS 2.x Integrity (I): {'"'+str(cvss20_integrityImpact)+'"'}
CVSS 2.x Availability (A): {'"'+str(cvss20_availabilityImpact)+'"'}
---
"""
    return header

# %%
def write_dict_to_md(cve, write_name):
    try:
        with open(write_name, 'w', encoding='utf-8') as file:
            v_dict = cve.__dict__
            header_properties = create_header_properties(cve)
            file.write(header_properties+ "\n")
            # Forma simple de escritura del contenido:
            # for key, value in v_dict.items():
            #     value = str(value).replace('[', '').replace(']', '')
            #     file.write(f"{key}\n{value}\n\n")
            file.write('**'+'Vulnerability ID' + '**' + "\n")
            file.write(cve.id+ "\n")
            file.write("\n"+'**'+'Description' + '**' + "\n")
            file.write(cve.descriptions[0].value + "\n") # Ojo, chequear items sin descripción
            file.write("\n"+'**'+'References to Advisories, Solutions, and Tools'+'**'+ "\n")
            if len(cve.references)>0:
                for r in range(len(cve.references)):
                    file.write(cve.references[r].source +' - '+cve.references[r].url+ "\n")
            file.write("\n"+ '**' + 'Weakness Enumeration'+'**'+ "\n")
            if hasattr(cve, 'weaknesses'):
                if len(cve.weaknesses) > 0:
                    for w in range(len(cve.weaknesses)):
                        file.write(cve.weaknesses[0].description[0].value +' - '+ 'https://cwe.mitre.org/data/definitions/'+cve.weaknesses[0].description[0].value[4:]+'.html')
        print(f"Archivo .md guardado en: {write_name}")
    except (OSError, IOError) as e:
        print(f"Error al escribir en el archivo {write_name}: {e}")

# %%
def get_nist_vulnerabilities(s_date, e_date):
    results = nvdlib.searchCVE(pubStartDate=s_date, pubEndDate=e_date)
    return results

# %% [markdown]
# **Ejecución principal**

# %%
vulnerabilities = get_nist_vulnerabilities(start_date, end_date)
print(f"Se han obtenido {str(len(vulnerabilities))} vulnerabilidades entre las fechas {start_date.strftime('%d/%m/%Y')} y {end_date.strftime('%d/%m/%Y')}")
# Out:
# Se han obtenido 112 vulnerabilidades entre las fechas 24/06/2024 y 25/06/2024

# %%
# Recorremos el listado de vulnerabilidades
for v in vulnerabilities:
    # Chequeamos que la fecha de publicación para el guardado y asignamos nombre del fichero final
    if v.published != '':
        folder_name = os.path.join(os.getcwd(), 'outputs', 'NIST', 'save_by_date', datetime.datetime.strptime(v.published, '%Y-%m-%dT%H:%M:%S.%f').strftime('%Y%m%d'))
        # file_name = v.id +'_'+ datetime.datetime.strptime(v.published, '%Y-%m-%dT%H:%M:%S.%f').strftime('%Y%m%d_%H%M')+'h.md' #temporal
        file_name = v.id + '_' + datetime.datetime.strptime(v.published, '%Y-%m-%dT%H:%M:%S.%f').strftime('%Y%m%d_%H%Mh') +'.md' 
    else:
        folder_name = os.path.join(os.getcwd(), 'outputs', 'NIST', 'save_by_date', 'no-pubish-date')
        file_name =   v.id + '_' + 'no-pubish-date'+'.md'
    # Creamos carpeta si no existe
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    # Controlamos el guardado de los archivos mediante un parámetro
    if save_as_md:
        write_name = os.path.join(folder_name, file_name)
        write_dict_to_md(v, write_name)
# Out:
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-32936_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-33278_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-33847_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-34027_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-34030_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-35247_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-36479_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-37021_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-37026_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-37825_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38384_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38663_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38664_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38667_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-39291_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-39292_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-4748_20240624_1415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-33687_20240624_1515h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-6285_20240624_1615h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-6287_20240624_1615h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-33879_20240624_1715h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-33880_20240624_1715h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-33881_20240624_1715h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38369_20240624_1715h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38373_20240624_1715h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-6104_20240624_1715h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2023-49793_20240624_1815h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2021-45785_20240624_1915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-37677_20240624_1915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-37679_20240624_1915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-37680_20240624_1915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-37732_20240624_1915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-34312_20240624_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-34313_20240624_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-37678_20240624_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-37681_20240624_2015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2023-45196_20240624_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-37759_20240624_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38892_20240624_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38894_20240624_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38895_20240624_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38896_20240624_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38897_20240624_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38902_20240624_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-38903_20240624_2115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2023-45195_20240624_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-33898_20240624_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-34991_20240624_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-36682_20240624_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-6290_20240624_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-6291_20240624_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-6292_20240624_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-6293_20240624_2215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2023-50029_20240624_2315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-22168_20240624_2315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-34988_20240624_2315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-34992_20240624_2315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-36681_20240624_2315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240624\CVE-2024-36683_20240624_2315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2023-6198_20240625_0215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-22385_20240625_0215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23140_20240625_0215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23141_20240625_0215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23142_20240625_0215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23143_20240625_0215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23144_20240625_0215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-6294_20240625_0215h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2023-5038_20240625_0315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23145_20240625_0315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23146_20240625_0315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23147_20240625_0315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23148_20240625_0315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23149_20240625_0315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-37000_20240625_0315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-37001_20240625_0315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-37002_20240625_0315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-6295_20240625_0315h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23150_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23151_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23152_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23153_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23154_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23155_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23156_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23157_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23158_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-23159_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-32855_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-36999_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-37003_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-37004_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-37005_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-37006_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-37007_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-4196_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-4197_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-6297_20240625_0415h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-4757_20240625_0615h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-4759_20240625_0615h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-5431_20240625_0615h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-3249_20240625_0715h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-34141_20240625_0915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-34142_20240625_0915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-4638_20240625_0915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-6028_20240625_0915h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-4639_20240625_1015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-4640_20240625_1015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-4641_20240625_1015h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-5216_20240625_1115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-6305_20240625_1115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-6306_20240625_1115h.md
# Archivo .md guardado en: c:\Users\jelopez\Documents\CyberProof\python\develop\get_cti_information\outputs\NIST\save_by_date\20240625\CVE-2024-6307_20240625_1115h.md
