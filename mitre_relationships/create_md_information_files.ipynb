# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

'''
Created on 2024-08-14
Last modified on 2024-08-14
@author: Juan Enrique López
@description: Jupyter Notebook cuyo cometido es generar archivos md con la información relativa a cada propiedad Mitre con la finalidad de filtrar vía Obsidian.

'''
# Out:
# '\nCreated on 2024-08-14\nLast modified on 2024-08-14\n@author: Juan Enrique López\n@description: Jupyter Notebook cuyo cometido es generar archivos md con la información relativa a cada propiedad Mitre con la finalidad de filtrar vía Obsidian.\n\n'

# %% [markdown]
# **IMPORTANTE - REQUERIMIENTOS PREVIOS**
#
# - Requiere haber ejecutado previamente dentro de este mismo módulo **mitre_relationships** el notebook **[stix2]_mitre_relationships.ipynb** y disponer de la carpeta "outputs/stix2".

# %%
import os
import pandas as pd
import shutil
# import requests
from stix2 import Filter, MemoryStore

# %% [markdown]
# #### **Parámetros**

# %%
mitre_domain = 'enterprise' # enterprise, mobile, ics
input_path = os.path.join(os.getcwd(),'outputs', 'stix2', mitre_domain, 'information')

# %%
output_folder = os.path.join(os.getcwd(),'outputs')
output_folder
# Out:
# 'c:\\Users\\jelopez\\Documents\\CyberProof\\python\\develop\\mitre_relationships\\outputs'

# %% [markdown]
# #### **Funciones**

# %%
def format_cols_for_md(column):
    '''
    Función para aplicar los reemplazos que permitan en el .md relacionar elementos.
    '''
    column = column.apply(lambda x: f'[[{x}]]')
    return column

# %%
def replace_chars(column):
    '''
    Función encargada de reemplazar caracteres en una columna dada con el objetivo de suprimir caracteres que enlazan dentro de Obsidian.
    '''
    if column.dtype == "object":  # Verifica que la columna sea de tipo string
        column = column.str.replace("['", '', regex=False)
        column = column.str.replace("']", '', regex=False)
        column = column.str.replace("'", '', regex=False)
    return column

# %%
def generate_technique_information_md(df, base_folder, mitre_property, mitre_domain):
    '''
    Función encargada de recorrer la tabla de técnicas y generar las estructura de carpetas junto con el archivo .md relativo a cada propiedad.
    '''
    # Iterar sobre cada fila del DataFrame
    for index, row in df.iterrows():
        # Obtener el technique_ID sin los corchetes
        technique_id = row['technique ID'].strip('[]')
        
        # Crear la ruta del archivo
        folder_path = os.path.join(base_folder, 'information_md', mitre_domain, mitre_property, technique_id)
        os.makedirs(folder_path, exist_ok=True)
        
        # Crear el nombre del archivo .md
        filename = f'{technique_id}.md'
        file_path = os.path.join(folder_path, filename)
        
        # Escribir el contenido en el archivo .md
        with open(file_path, 'w') as file:
            # Propiedades
            file.write("---\n")
            file.write("Technique: true\n")
            file.write("---\n\n")
            
            # Escribir el título con technique_ID
            file.write(f"### {technique_id}\n\n")
            
            # Escribir los detalles de la técnica
            file.write(f"**technique ID**\n{row['technique ID']}\n\n")
            file.write(f"**technique**\n{row['technique']}\n\n")
            file.write(f"**technique url**\n{row['technique url']}\n\n")
            file.write(f"**technique description**\n{row['technique description']}\n\n")
            file.write(f"**matrix domains**\n{row['matrix domains']}\n\n")
            file.close()
        
        print(f"Archivo '{filename}' creado en la carpeta '{folder_path}' con éxito.")

# %%
def generate_tactic_information_md(df, base_folder, mitre_property, mitre_domain):
    '''
    Función encargada de recorrer la tabla de tácticas y generar las estructura de carpetas junto con el archivo .md relativo a cada propiedad.
    '''
    # Iterar sobre cada fila del DataFrame
    for index, row in df.iterrows():
        # Obtener el tactic_ID sin los corchetes
        tactic_id = row['tactic ID'].strip('[]')
        
        # Crear la ruta del archivo
        folder_path = os.path.join(base_folder, 'information_md',mitre_domain, mitre_property, tactic_id)
        os.makedirs(folder_path, exist_ok=True)
        
        # Crear el nombre del archivo .md
        filename = f'{tactic_id}.md'
        file_path = os.path.join(folder_path, filename)
        
        # Escribir el contenido en el archivo .md
        with open(file_path, 'w') as file:
            # Propiedades
            file.write("---\n")
            file.write("Tactic: true\n")
            file.write("---\n\n")
            
            # Escribir el título con tactic_ID
            file.write(f"### {tactic_id}\n\n")
            
            # Escribir los detalles de la táctica
            file.write(f"**tactic ID**\n{row['tactic ID']}\n\n")
            file.write(f"**tactic**\n{row['tactic']}\n\n")
            file.write(f"**tactic url**\n{row['tactic url']}\n\n")
            file.write(f"**tactic description**\n{row['tactic description']}\n\n")
            file.write(f"**matrix domains**\n{row['matrix domains']}\n\n")
            file.close()
        
        print(f"Archivo '{filename}' creado en la carpeta '{folder_path}' con éxito.")

# %%
def generate_platform_information_md(df, base_folder, mitre_property, mitre_domain):
    '''
    Función encargada de recorrer la tabla de plataformas y generar las estructura de carpetas junto con el archivo .md relativo a cada propiedad.
    '''
    for index, row in df.iterrows():
        platform = row['platform'].strip('[]')
        folder_path = os.path.join(base_folder, 'information_md', mitre_domain, mitre_property, platform)
        os.makedirs(folder_path, exist_ok=True)
        filename = f'{platform}.md'
        file_path = os.path.join(folder_path, filename)
        
        with open(file_path, 'w') as file:
            file.write("---\n")
            file.write("Platform: true\n")
            file.write("---\n\n")
        
            file.write(f"### {platform}\n\n")

            file.write(f"**platform**\n{row['platform']}\n\n")
            file.close()

        print(f"Archivo '{filename}' creado en la carpeta '{folder_path}' con éxito.")

# %%
def generate_datasource_information_md(df, base_folder, mitre_property, mitre_domain):
    '''
    Función encargada de recorrer la tabla de plataformas y generar las estructura de carpetas junto con el archivo .md relativo a cada propiedad.
    '''
    for index, row in df.iterrows():
        data_source_id = row['data source ID'].strip('[]')
        
        # Crear la ruta del archivo
        folder_path = os.path.join(base_folder, 'information_md', mitre_domain, mitre_property, data_source_id)
        os.makedirs(folder_path, exist_ok=True)
        
        filename = f'{data_source_id}.md'
        file_path = os.path.join(folder_path, filename)
        
        with open(file_path, 'w') as file:
            file.write("---\n")
            file.write("Data source: true\n")
            file.write("---\n\n")
            
            file.write(f"### {data_source_id}\n\n")
            
            file.write(f"**data source ID**\n{row['data source ID']}\n\n")
            file.write(f"**data source**\n{row['data source']}\n\n")
            file.write(f"**data source url**\n{row['data source url']}\n\n")
            file.write(f"**data source description**\n{row['data source description']}\n\n")
            file.write(f"**matrix domains**\n{row['matrix domains']}\n\n")
            file.close()
        
        print(f"Archivo '{filename}' creado en la carpeta '{folder_path}' con éxito.")

# %%
def generate_group_information_md(df, base_folder, mitre_property, mitre_domain):
    '''
    Función encargada de recorrer la tabla de grupos y generar las estructura de carpetas junto con el archivo .md relativo a cada propiedad.
    '''
    for index, row in df.iterrows():
        group_id = row['group ID'].strip('[]')
        
        folder_path = os.path.join(base_folder, 'information_md', mitre_domain, mitre_property, group_id)
        os.makedirs(folder_path, exist_ok=True)
        
        filename = f'{group_id}.md'
        file_path = os.path.join(folder_path, filename)
        
        with open(file_path, 'w') as file:
            file.write("---\n")
            file.write("Group: true\n")
            file.write("---\n\n")
            
            file.write(f"### {group_id}\n\n")
            
            file.write(f"**group ID**\n{row['group ID']}\n\n")
            file.write(f"**group**\n{row['group']}\n\n")
            file.write(f"**group aliases**\n{row['group aliases']}\n\n")
            file.write(f"**group url**\n{row['group url']}\n\n")
            # file.write(f"**group description**\n{row['group description']}\n\n")
            file.write(f"**group description**\n{row['group description'].replace('[', '').replace(']', '')}\n\n")
            file.write(f"**matrix domains**\n{row['matrix domains']}\n\n")
            file.close()
        
        print(f"Archivo '{filename}' creado en la carpeta '{folder_path}' con éxito.")

# %%
def generate_software_information_md(df, base_folder, mitre_property, mitre_domain):
    '''
    Función encargada de recorrer la tabla de software y generar las estructura de carpetas junto con el archivo .md relativo a cada propiedad.
    '''
    for index, row in df.iterrows():
        software_id = row['software ID'].strip('[]')
        folder_path = os.path.join(base_folder, 'information_md', mitre_domain, mitre_property, software_id)
        os.makedirs(folder_path, exist_ok=True)
    
        filename = f'{software_id}.md'
        file_path = os.path.join(folder_path, filename)
        
        with open(file_path, 'w') as file:
            file.write("---\n")
            file.write("Software: true\n")
            file.write("---\n\n")
        
            file.write(f"### {software_id}\n\n")

            file.write(f"**software ID**\n{row['software ID']}\n\n")
            file.write(f"**software**\n{row['software']}\n\n")
            file.write(f"**software type**\n{row['software type']}\n\n")
            file.write(f"**software url**\n{row['software url']}\n\n")
            file.write(f"**software description**\n{row['software description']}\n\n")
            file.write(f"**matrix domains**\n{row['matrix domains']}\n\n")
            file.close()
        print(f"Archivo '{filename}' creado en la carpeta '{folder_path}' con éxito.")

# %% [markdown]
# #### **Ejecución**

# %% [markdown]
# ##### **1. Técnicas**

# %%
input_file = f'[MITRE]_{mitre_domain}_techniques.csv'
techniques_information_df = pd.read_csv(os.path.join(input_path, 'techniques', input_file), sep=';', quotechar='"')
techniques_information_df.head(3)
# Out:
#   technique_ID                      technique  \
# 0    T1055.011  Extra Window Memory Injection
# 1    T1053.005                 Scheduled Task
# 2    T1205.002                 Socket Filters
#
#                                    technique_url  \
# 0  https://attack.mitre.org/techniques/T1055/011
# 1  https://attack.mitre.org/techniques/T1053/005
# 2  https://attack.mitre.org/techniques/T1205/002
#
#                                technique_description  technique_deprecated  \
# 0  Adversaries may inject malicious code into pro...                 False
# 1  Adversaries may abuse the Windows Task Schedul...                 False
# 2  Adversaries may attach filters to a network so...                 False
#
#    technique_revoked         matrix_domains
# 0              False  ['enterprise-attack']
# 1              False  ['enterprise-attack']
# 2              False  ['enterprise-attack']

# %%
column_list = ['technique_ID','tactic_ID','platform_ID','platform','group_ID','data_source_ID']
for col in techniques_information_df.columns:
    if col in column_list:
        print(col)
        techniques_information_df[col] = format_cols_for_md(techniques_information_df[col])
    else:
        techniques_information_df[col] =  replace_chars(techniques_information_df[col])
techniques_information_df.columns = techniques_information_df.columns.str.replace('_', ' ', regex=False)
techniques_information_df.head(3)
# Out:
# technique_ID
#     technique ID                      technique  \
# 0  [[T1055.011]]  Extra Window Memory Injection
# 1  [[T1053.005]]                 Scheduled Task
# 2  [[T1205.002]]                 Socket Filters
#
#                                    technique url  \
# 0  https://attack.mitre.org/techniques/T1055/011
# 1  https://attack.mitre.org/techniques/T1053/005
# 2  https://attack.mitre.org/techniques/T1205/002
#
#                                technique description  technique deprecated  \
# 0  Adversaries may inject malicious code into pro...                 False
# 1  Adversaries may abuse the Windows Task Schedul...                 False
# 2  Adversaries may attach filters to a network so...                 False
#
#    technique revoked     matrix domains
# 0              False  enterprise-attack
# 1              False  enterprise-attack
# 2              False  enterprise-attack

# %%
generate_technique_information_md(techniques_information_df, output_folder, 'techniques', mitre_domain)
# Out:
# Archivo 'T1055.011.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\techniques\T1055.011' con éxito.
# Archivo 'T1053.005.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\techniques\T1053.005' con éxito.
# Archivo 'T1205.002.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\techniques\T1205.002' con éxito.
# Archivo 'T1560.001.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\techniques\T1560.001' con éxito.
# Archivo 'T1021.005.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\techniques\T1021.005' con éxito.
# ...

# %% [markdown]
# ##### **2. Tácticas**

# %%
input_file = f'[MITRE]_{mitre_domain}_tactics.csv'
tactics_information_df = pd.read_csv(os.path.join(input_path, 'tactics', input_file), sep=';', quotechar='"')
tactics_information_df.head(3)
# Out:
#   tactic_ID             tactic                               tactic_url  \
# 0    TA0006  Credential Access  https://attack.mitre.org/tactics/TA0006
# 1    TA0002          Execution  https://attack.mitre.org/tactics/TA0002
# 2    TA0040             Impact  https://attack.mitre.org/tactics/TA0040
#
#                                   tactic_description         matrix_domains
# 0  The adversary is trying to steal account names...  ['enterprise-attack']
# 1  The adversary is trying to run malicious code....  ['enterprise-attack']
# 2  The adversary is trying to manipulate, interru...  ['enterprise-attack']

# %%
column_list = ['technique_ID','tactic_ID','platform_ID','platform','group_ID','data_source_ID']
for col in tactics_information_df.columns:
    if col in column_list:
        print(col)
        tactics_information_df[col] = format_cols_for_md(tactics_information_df[col])
    else:
        tactics_information_df[col] =  replace_chars(tactics_information_df[col])
tactics_information_df.columns = tactics_information_df.columns.str.replace('_', ' ', regex=False)
tactics_information_df.head(3)
# Out:
# tactic_ID
#     tactic ID             tactic                               tactic url  \
# 0  [[TA0006]]  Credential Access  https://attack.mitre.org/tactics/TA0006
# 1  [[TA0002]]          Execution  https://attack.mitre.org/tactics/TA0002
# 2  [[TA0040]]             Impact  https://attack.mitre.org/tactics/TA0040
#
#                                   tactic description     matrix domains
# 0  The adversary is trying to steal account names...  enterprise-attack
# 1  The adversary is trying to run malicious code....  enterprise-attack
# 2  The adversary is trying to manipulate, interru...  enterprise-attack

# %%
generate_tactic_information_md(tactics_information_df, output_folder, 'tactics', mitre_domain)
# Out:
# Archivo 'TA0006.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\tactics\TA0006' con éxito.
# Archivo 'TA0002.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\tactics\TA0002' con éxito.
# Archivo 'TA0040.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\tactics\TA0040' con éxito.
# Archivo 'TA0003.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\tactics\TA0003' con éxito.
# Archivo 'TA0004.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\tactics\TA0004' con éxito.
# ...

# %% [markdown]
# ##### **3. Plataformas**

# %%
input_file = f'[MITRE]_{mitre_domain}_platforms.csv'
platforms_information_df = pd.read_csv(os.path.join(input_path, 'platforms', input_file), sep=';', quotechar='"')
platforms_information_df.head(3)
# Out:
#            platform
# 0          Azure AD
# 1        Containers
# 2  Google Workspace

# %%
column_list = ['technique_ID','tactic_ID','platform_ID','platform','group_ID','data_source_ID']
for col in platforms_information_df.columns:
    if col in column_list:
        print(col)
        platforms_information_df[col] = format_cols_for_md(platforms_information_df[col])
    else:
        platforms_information_df[col] =  replace_chars(platforms_information_df[col])
platforms_information_df.columns = platforms_information_df.columns.str.replace('_', ' ', regex=False)
platforms_information_df.head(3)
# Out:
# platform
#                platform
# 0          [[Azure AD]]
# 1        [[Containers]]
# 2  [[Google Workspace]]

# %%
generate_platform_information_md(platforms_information_df, output_folder, 'platforms', mitre_domain)
# Out:
# Archivo 'Azure AD.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\platforms\Azure AD' con éxito.
# Archivo 'Containers.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\platforms\Containers' con éxito.
# Archivo 'Google Workspace.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\platforms\Google Workspace' con éxito.
# Archivo 'IaaS.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\platforms\IaaS' con éxito.
# Archivo 'Linux.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\platforms\Linux' con éxito.
# ...

# %% [markdown]
# ##### **4. Data Sources**

# %%
input_file = f'[MITRE]_{mitre_domain}_datasources.csv'
datasources_information_df = pd.read_csv(os.path.join(input_path, 'datasources', input_file), sep=';', quotechar='"')
datasources_information_df.head(3)
# Out:
#   data_source_ID      data_source  \
# 0         DS0029  Network Traffic
# 1         DS0030         Instance
# 2         DS0019          Service
#
#                                data_source_url  \
# 0  https://attack.mitre.org/datasources/DS0029
# 1  https://attack.mitre.org/datasources/DS0030
# 2  https://attack.mitre.org/datasources/DS0019
#
#                              data_source_description  data_source_deprecated  \
# 0  Data transmitted across a network (ex: Web, DN...                   False
# 1  A virtual server environment which runs worklo...                   False
# 2  A computer process that is configured to execu...                   False
#
#    data_source_revoked                          matrix_domains
# 0                False  ['enterprise-attack', 'mobile-attack']
# 1                False                   ['enterprise-attack']
# 2                False                   ['enterprise-attack']

# %%
column_list = ['technique_ID','tactic_ID','platform_ID','platform','group_ID','data_source_ID']
for col in datasources_information_df.columns:
    if col in column_list:
        print(col)
        datasources_information_df[col] = format_cols_for_md(datasources_information_df[col])
    else:
        datasources_information_df[col] =  replace_chars(datasources_information_df[col])
datasources_information_df.columns = datasources_information_df.columns.str.replace('_', ' ', regex=False)
datasources_information_df.head(3)
# Out:
# data_source_ID
#   data source ID      data source  \
# 0     [[DS0029]]  Network Traffic
# 1     [[DS0030]]         Instance
# 2     [[DS0019]]          Service
#
#                                data source url  \
# 0  https://attack.mitre.org/datasources/DS0029
# 1  https://attack.mitre.org/datasources/DS0030
# 2  https://attack.mitre.org/datasources/DS0019
#
#                              data source description  data source deprecated  \
# 0  Data transmitted across a network (ex: Web, DN...                   False
# 1  A virtual server environment which runs worklo...                   False
# 2  A computer process that is configured to execu...                   False
#
#    data source revoked                    matrix domains
# 0                False  enterprise-attack, mobile-attack
# 1                False                 enterprise-attack
# 2                False                 enterprise-attack

# %%
generate_datasource_information_md(datasources_information_df, output_folder, 'data sources', mitre_domain)
# Out:
# Archivo 'DS0029.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\data sources\DS0029' con éxito.
# Archivo 'DS0030.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\data sources\DS0030' con éxito.
# Archivo 'DS0019.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\data sources\DS0019' con éxito.
# Archivo 'DS0022.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\data sources\DS0022' con éxito.
# Archivo 'DS0009.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\data sources\DS0009' con éxito.
# ...

# %% [markdown]
# ##### **5. Grupos**

# %%
input_file = f'[MITRE]_{mitre_domain}_groups.csv'
groups_information_df = pd.read_csv(os.path.join(input_path, 'groups', input_file), sep=';', quotechar='"')
groups_information_df.head(3)
# Out:
#   group_ID    group                                group_aliases  \
# 0    G0001    Axiom                        ['Axiom', 'Group 72']
# 1    G0002   Moafee                                   ['Moafee']
# 2    G0003  Cleaver  ['Cleaver', 'Threat Group 2889', 'TG-2889']
#
#                                group_url  \
# 0  https://attack.mitre.org/groups/G0001
# 1  https://attack.mitre.org/groups/G0002
# 2  https://attack.mitre.org/groups/G0003
#
#                                    group_description  group_deprecated  \
# 0  [Axiom](https://attack.mitre.org/groups/G0001)...             False
# 1  [Moafee](https://attack.mitre.org/groups/G0002...             False
# 2  [Cleaver](https://attack.mitre.org/groups/G000...             False
#
#    group_revoked         matrix_domains
# 0          False  ['enterprise-attack']
# 1          False  ['enterprise-attack']
# 2          False  ['enterprise-attack']

# %%
column_list = ['technique_ID','tactic_ID','platform_ID','platform','group_ID','data_source_ID']
for col in groups_information_df.columns:
    if col in column_list:
        print(col)
        groups_information_df[col] = format_cols_for_md(groups_information_df[col])
    else:
        groups_information_df[col] =  replace_chars(groups_information_df[col])
groups_information_df.columns = groups_information_df.columns.str.replace('_', ' ', regex=False)
groups_information_df.head(3)
# Out:
# group_ID
#     group ID    group                        group aliases  \
# 0  [[G0001]]    Axiom                      Axiom, Group 72
# 1  [[G0002]]   Moafee                               Moafee
# 2  [[G0003]]  Cleaver  Cleaver, Threat Group 2889, TG-2889
#
#                                group url  \
# 0  https://attack.mitre.org/groups/G0001
# 1  https://attack.mitre.org/groups/G0002
# 2  https://attack.mitre.org/groups/G0003
#
#                                    group description  group deprecated  \
# 0  [Axiom](https://attack.mitre.org/groups/G0001)...             False
# 1  [Moafee](https://attack.mitre.org/groups/G0002...             False
# 2  [Cleaver](https://attack.mitre.org/groups/G000...             False
#
#    group revoked     matrix domains
# 0          False  enterprise-attack
# 1          False  enterprise-attack
# 2          False  enterprise-attack

# %%
generate_group_information_md(groups_information_df, output_folder, 'groups', mitre_domain)
# Out:
# Archivo 'G0001.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\groups\G0001' con éxito.
# Archivo 'G0002.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\groups\G0002' con éxito.
# Archivo 'G0003.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\groups\G0003' con éxito.
# Archivo 'G0004.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\groups\G0004' con éxito.
# Archivo 'G0005.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\groups\G0005' con éxito.
# ...

# %% [markdown]
# ##### **6. Software**

# %%
input_file = f'[MITRE]_{mitre_domain}_software.csv'
software_information_df = pd.read_csv(os.path.join(input_path, 'software', input_file), sep=';', quotechar='"')
software_information_df.head(3)
# Out:
#   software_ID        software software_type  \
# 0       S0001  Trojan.Mebromi       malware
# 1       S0002        Mimikatz          tool
# 2       S0003         RIPTIDE       malware
#
#                               software_url  \
# 0  https://attack.mitre.org/software/S0001
# 1  https://attack.mitre.org/software/S0002
# 2  https://attack.mitre.org/software/S0003
#
#                                 software_description  software_deprecated  \
# 0  [Trojan.Mebromi](https://attack.mitre.org/soft...                False
# 1  [Mimikatz](https://attack.mitre.org/software/S...                False
# 2  [RIPTIDE](https://attack.mitre.org/software/S0...                False
#
#    software_revoked         matrix_domains
# 0             False  ['enterprise-attack']
# 1             False  ['enterprise-attack']
# 2             False  ['enterprise-attack']

# %%
column_list = ['technique_ID','tactic_ID','platform_ID','platform','group_ID','data_source_ID']
for col in software_information_df.columns:
    if col in column_list:
        print(col)
        software_information_df[col] = format_cols_for_md(software_information_df[col])
    else:
        software_information_df[col] =  replace_chars(software_information_df[col])
software_information_df.columns = software_information_df.columns.str.replace('_', ' ', regex=False)
software_information_df.head(3)
# Out:
#   software ID        software software type  \
# 0       S0001  Trojan.Mebromi       malware
# 1       S0002        Mimikatz          tool
# 2       S0003         RIPTIDE       malware
#
#                               software url  \
# 0  https://attack.mitre.org/software/S0001
# 1  https://attack.mitre.org/software/S0002
# 2  https://attack.mitre.org/software/S0003
#
#                                 software description  software deprecated  \
# 0  [Trojan.Mebromi](https://attack.mitre.org/soft...                False
# 1  [Mimikatz](https://attack.mitre.org/software/S...                False
# 2  [RIPTIDE](https://attack.mitre.org/software/S0...                False
#
#    software revoked     matrix domains
# 0             False  enterprise-attack
# 1             False  enterprise-attack
# 2             False  enterprise-attack

# %%
generate_software_information_md(software_information_df, output_folder, 'software', mitre_domain)
# Out:
# Archivo 'S0001.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\software\S0001' con éxito.
# Archivo 'S0002.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\software\S0002' con éxito.
# Archivo 'S0003.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\software\S0003' con éxito.
# Archivo 'S0004.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\software\S0004' con éxito.
# Archivo 'S0005.md' creado en la carpeta 'c:\Users\jelopez\Documents\CyberProof\python\develop\mitre_relationships\outputs\information_md\enterprise\software\S0005' con éxito.
# ...
