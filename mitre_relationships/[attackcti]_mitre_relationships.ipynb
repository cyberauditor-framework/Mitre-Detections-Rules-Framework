# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
Created on 2024-06-18

@author: Juan Enrique López Marcos

@description: Jupyter Notebook creado para obtener las relaciones entre items de MITRE principalmente con las Técnicas (Tácticas, Data Sources, Software, Grupos). Adicionalmente se incluye una funcionalidad que permite retornar el listado de reglas de detección por técnica disponibles en CP. 

"""
# Out:
# '\nCreated on 2024-06-18\n\n@author: Juan Enrique López Marcos\n\n@description: Jupyter Notebook creado para obtener las relaciones entre items de MITRE principalmente con las Técnicas (Tácticas, Data Sources, Software, Grupos). Adicionalmente se incluye una funcionalidad que permite retornar el listado de reglas de detección por técnica disponibles en CP. \n\n'

# %% [markdown]
# **Índice de contenidos**
#
# [1. TÉCNICAS - TÁCTICAS]()
#
# - [1.1 Tablas intermedias (N:N)]()
#
# - [1.2 Técnicas - Tácticas (1:N)]()
#
# - [1.3 Tácticas - Técnicas (1:N)]()
#
# [2. DATA SOURCES - TÉCNICAS]()
#
# - [2.1 Tablas intermedias (N:N)]()
#
# - [2.2 Técnicas - Data Sources (1:N)]()
#
# - [2.3 Data Sources - Técnicas (1:N)]()
#
# [3. GRUPOS - TÉCNICAS]()
#
# - [3.1 Tablas intermedias (N:N)]()
#
# - [3.2 Grupos - Técnicas (1:N)]()
#
# - [3.3 Técnicas - Grupos (1:N)]()
#
# [4. SOFTWARE - TÉCNICAS]()
#
# - [4.1 Tablas intermedias (N:N)]()
#
# - [4.2 Técnicas - Software (1:N)]()
#
# - [4.3 Software - Técnicas (1:N)]()
#
# [5. GRUPOS - SOFTWARE]()
#
# - [4.1 Tablas intermedias (N:N)]()
#
# - [4.2 Grupos - Software (1:N)]()
#
# - [4.3 Software - Grupos (1:N)]()
#
# [6. PLATAFORMAS - TÉCNICAS]()
#
# - [6.1 Tablas intermedias (N:N)]()
#
# - [6.2 Técnica - Plataformas (1:N)]()
#
# - [6.3 Plataforma - Técnicas (1:N)]()
#
#
# [BONUS. GENERACIÓN LISTADO DE REGLAS DE DETECCIÓN POR TÉCNICA]()

# %% [markdown]
# **Descripción de los outputs**

# %% [markdown]
# <h3 style="background-color: #FF5733; color: black;">
#     1. TÉCNICAS - TÁCTICAS
# </h3>
#
# #### 1.1 Tablas intermedias (N:N)
#
# Guardado en: *inter_techniques_tactics*
#
# - Relación N a N de técnicas y tácticas MITRE. Campos: tactic, technique_id, technique, url_technique,tactic_id, tactic_description, url_tactic.
#     - [MITRE]_enterprise_n2n_techniques_tactics_df_ddmmYY_hhmm_h.csv
# - Relación N a N de técnicas y tácticas CyberProof (filtro sobre aquellas TTP's disponibles con regla de detección). Campos: tactic, technique_id, technique, url_technique,tactic_id, tactic_description, url_tactic
#     - [CP]_enterprise_n2n_techniques_tactics_ddmmYY_hhmm_h.csv
# - Relación N a N de técnicas y tácticas que NO disponemos en CyberProof. Campos: tactic, technique_id, technique, url_technique,tactic_id, tactic_description, url_tactic
#     - [NOCP]_enterprise_n2n_techniques_tactics_ddmmYY_hhmm_h.csv
#
#
# #### 1.2 Técnicas - Tácticas (1:N)
#
# Guardado en: *technique_tactics_1N*
#
# - Lista de técnicas únicas con las tácticas asociadas MITRE. Campos: technique_id, technique, url_technique, tactic_id, tactic, tactic_description, url_tactic.
#     - [MITRE]_techniques_with_tactics_ddmmYY_hhmm_h.csv
# - Lista de técnicas únicas con las tácticas asociadas CyberProof. Campos: technique_id, technique, url_technique, tactic_id, tactic, tactic_description, url_tactic.
#     - [CP]_techniques_with_tactics_ddmmYY_hhmm_h.csv
# - Lista de técnicas únicas con las tácticas asociadas que NO disponemos en CyberProof. Campos: technique_id, technique, url_technique, tactic_id, tactic, tactic_description, url_tactic.
#     - [NOCP]_techniques_with_tactics_ddmmYY_hhmm_h.csv
#
#
# #### 1.3 Tácticas - Técnicas (1:N)
#
# Guardado en: *tactic_techniques_1N*
#
# - Lista de tácticas únicas con las técnicas asociadas MITRE. Campos: technique_id, technique, url_technique, tactic_id, tactic, tactic_description, url_tactic.
#     - [MITRE]_techniques_with_tactics_ddmmYY_hhmm_h.csv
# - Lista de tácticas únicas con las técnicas asociadas CyberProof. Campos: technique_id, technique, url_technique, tactic_id, tactic, tactic_description, url_tactic.
#     - [CP]_techniques_with_tactics_ddmmYY_hhmm_h.csv
# - Lista de tácticas únicas con las técnicas asociadas que NO disponemos en CyberProof. Campos: technique_id, technique, url_technique, tactic_id, tactic, tactic_description, url_tactic.
#     - [NOCP]_techniques_with_tactics_ddmmYY_hhmm_h.csv
#
# *Nota: Tenemos todas las tácticas cubiertas por al menos una regla de deteccion (TTP asociada) y tenemos 1 cubierta por todas TTP's disponibles (TA0040)

# %% [markdown]
# <h3 style="background-color: #FF5733; color: black;">
#     2. DATA SOURCES - TÉCNICAS
# </h3>
#
# #### 2.1 Tablas intermedias (N:N)
#
# Guardado en: *inter_data_sources_techniques*
#
# - Lista sencilla de data sources. Campos: data_source_id, data_source, data_source_description, url_data_source
#     - [MITRE]_data_sources
#
# - Relación N:N de Data Sources y Técnicas (todos los casos, incuyendo técnicas sin data source y data sources sin técnica). Campos: technique_id, url_technique, data_source_id, data_source, data_source_detail, url_data_source
#     - [MITRE]_enterprise_n2n_all_techniques_data_sources_ddmmYY_hhmm_h.csv
#
# - Relación N:N de Data Sources y Técnicas (SÓLO aquellos relacionados). Campos: technique_id, url_technique, data_source_id, data_source, data_source_detail, url_data_source
#     - [MITRE]_enterprise_n2n_techniques_data_sources_ddmmYY_hhmm_h.csv
#
# *Nota: TTP's únicas sin data source asociado: 40. TTP's únicas con data source asociado: 597. Data sources únicas sin TTP asociada: 37. Data sources únicas sin TTP asociada: 5
#
# - Relación N:N de Data Sources y Técnicas (SÓLO DISPONIBLES EN CP y relacionados). Campos: technique_id, url_technique, data_source_id, data_source, data_source_detail, url_data_source
#     - [CP]_enterprise_n2n_techniques_data_sources_ddmmYY_hhmm_h.csv
#
# - Relación N:N de Data Sources y Técnicas (NO DISPONIBLES EN CP y relacionados). Campos: technique_id, url_technique, data_source_id, data_source, data_source_detail, url_data_source
#     - [NOCP]_enterprise_n2n_techniques_data_sources_ddmmYY_hhmm_h.csv
#
#
#
# #### 2.2 Técnicas - Data Sources (1:N)
#
# Guardado en: *technique_data_sources_1N*
#
# - Relación 1:N entre Técnicas y Data Sources (todas las disponibles en MITRE). Campos: technique_id, url_technique, data_source_id, data_source, data_source_detail, url_data_source
#     - [MITRE]_techniques_with_data_sources_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Técnicas y Data Sources (SÓLO DISPONIBLES EN CP). Campos: technique_id, url_technique, data_source_id, data_source, data_source_detail, url_data_source
#     - [CP]_techniques_with_data_sources_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Técnicas y Data Sources (NO DISPONIBLES EN CP). Campos: technique_id, url_technique, data_source_id, data_source, data_source_detail, url_data_source
#     - [NOCP]_techniques_with_data_sources_ddmmYY_hhmm_h.csv
#
# *Nota: Disponemos de 597 TTP's con regla de detección asociada a uno o más Data soruces. 103 TTP's no disponibles y 40 TTP's no tienen Data source asociado.
#
#
# #### 2.3 Data Sources - Técnicas (1:N)
#
# Guardado en: *data_source_techniques_1N*
#
# - Relación 1:N entre Data Sources y Técnicas (todas las disponibles en MITRE). Campos: technique_id, url_technique, data_source_id, data_source, data_source_detail, url_data_source
#     - [MITRE]_data_source_with_techniques_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Data Sources y Técnicas (SÓLO DISPONIBLES EN CP). Campos: technique_id, url_technique, data_source_id, data_source, data_source_detail, url_data_source
#     - [CP]_data_source_with_techniques_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Data Sources y Técnicas (NO DISPONIBLES EN CP). Campos: technique_id, url_technique, data_source_id, data_source, data_source_detail, url_data_source
#     - [NOCP]_data_source_with_techniques_ddmmYY_hhmm_h.csv

# %% [markdown]
# <h3 style="background-color: #FF5733; color: black;">
#     3. GRUPOS - TÉCNICAS
# </h3>
#
# #### 3.1 Tablas intermedias (1:N y N:N)
#
# Guardado en: *inter_groups_techniques*
#
# - Lista sencilla de todos los grupos (1:N). Campos: group_id, group, url_group, technique_id, technique, url_technique
#     - [MITRE]_all_groups_ddmmYY_hhmm_h.csv
#
# - Misma lista que la anterior pero filtrada por matriz de ataque enterprise (1:N). Campos: group_id, group, url_group, technique_id, technique, url_technique.
#     - [MITRE]_enterprise_groups_ddmmYY_hhmm_h.csv
#
# - Lista completa de grupos relacionados con toda la información relevante. Campos: group_id, group, url_group, technique_id, technique, url_technique.
#     - [MITRE]_enterprise_all_data_groups_ddmmYY_hhmm_h.csv
#
# - Filtramos la lista completa por las técnicas disponibles en CP. Campos: group_id, group, url_group, technique_id, technique, url_technique.
#     - [CP]_enterprise_all_data_groups_ddmmYY_hhmm_h.csv
#
# - Filtramos la lista completa por las técnicas NO disponibles en CP. Campos: group_id, group, url_group, technique_id, technique, url_technique.
#     - [NOCP]_enterprise_all_data_groups_ddmmYY_hhmm_h.csv
#
# #### 3.2 Grupos - Técnicas (1:N)
#
# Guardado en: *group_techniques_1N*
#
# - Relación 1:N entre Grupos y Técnicas (todas las disponibles en MITRE). Campos: ggroup_id, group, url_group, technique_id, technique, url_technique.
#     - [MITRE]_groups_with_techniques_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Grupos y Técnicas (SÓLO DISPONIBLES EN CP). Campos: group_id, group, url_group, technique_id, technique, url_technique.
#     - [CP]_groups_with_techniques_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Grupos y Técnicas (NO DISPONIBLES EN CP). Campos: group_id, group, url_group, technique_id, technique, url_technique.
#     - [NOCP]_groups_with_techniques_ddmmYY_hhmm_h.csv
#
# #### 3.3 Técnicas - Grupos (1:N)
#
# Guardado en: *technique_groups_1N*
#
# - Relación 1:N entre Técnicas y Grupos (todas las disponibles en MITRE). Campos: group_id, group, url_group, technique_id, technique, url_technique.
#     - [MITRE]_techniques_with_groups_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Técnicas y Grupos (SÓLO DISPONIBLES EN CP). Campos: group_id, group, url_group, technique_id, technique, url_technique.
#     - [CP]_techniques_with_groups_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Técnicas y Grupos (NO DISPONIBLES EN CP). Campos: group_id, group, url_group, technique_id, technique, url_technique.
#     - [NOCP]_techniques_with_groups_ddmmYY_hhmm_h.csv

# %% [markdown]
# <h3 style="background-color: #FF5733; color: black;">
#     4. SOFTWARE - TÉCNICAS
# </h3>
#
# #### 4.1 Tablas intermedias (1:N y N:N)
#
# Guardado en: *inter_software_techniques*
#
# - Lista sencilla de todos los software, incluyendo diferentes de enterprise (1:N). Campos: software_id, software, software_aliases, type, url, matrix
#     - [MITRE]_all_software_ddmmYY_hhmm_h.csv
#
# - Lista sencilla de todos los software enterprise (1:N). Campos: software_id, software, software_aliases, type, url, matrix
#     - [MITRE]_enterprise_software_ddmmYY_hhmm_h.csv
#
# - Lista completa de software relacionados con las técnicas y toda la información disponible (sólo enterprise). Campos: type, id, url, matrix, created, modified, created_by_ref, modified_by_ref, external_references, object_marking_refs, mitre_version, mitre_attack_spec_version, mitre_deprecated, technique, technique_id, technique_description, tactic, technique_detection, platform, data_sources, defense_bypassed, permissions_required, effective_permissions, system_requirements, network_requirements, remote_support, contributors, tactic_type, impact_type, is_subtechnique, software_id, software, software_aliases, software_description, software_type, url_software, mitre_domains, url_technique.
#     - [MITRE]n2n_main_techniques_software_ddmmYY_hhmm_h.csv
#
# - Lista reducida a los campos más importantes. Campos: technique_id, technique, url_technique, software_id, software, software_description, software_type, url_software.
#     - [MITRE]_n2n_techniques_software_ddmmYY_hhmm_h.csv
#
# - Filtramos la lista completa por las técnicas disponibles en CP. Campos: technique_id, technique, url_technique, software_id, software, software_description, software_type, url_software.
#     - [CP]_n2n_techniques_software_ddmmYY_hhmm_h.csv
#
# - Filtramos la lista completa por las técnicas NO disponibles en CP. Campos: technique_id, technique, url_technique, software_id, software, software_description, software_type, url_software.
#     - [NOCP]_n2n_techniques_software_ddmmYY_hhmm_h.csv
#
#
# #### 4.2 Técnica - Software (1:N)
#
# Guardado en: *technique_software_1N*
#
# - Relación 1:N entre Técnica y Software (todas las disponibles en MITRE). Campos: technique_id, technique, url_technique, software_id, software, software_description, software_type, url_software.
#     - [MITRE]_technique_with_software_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Técnica y Software  (SÓLO DISPONIBLES EN CP). Campos: technique_id, technique, url_technique, software_id, software, software_description, software_type, url_software.
#     - [CP]_technique_with_software_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Técnica y Software  (NO DISPONIBLES EN CP). Campos: technique_id, technique, url_technique, software_id, software, software_description, software_type, url_software.
#     - [NOCP]_technique_with_software_ddmmYY_hhmm_h.csv
#
#
# #### 4.3 Software - Técnicas (1:N)
#
# Guardado en: *software_techniques_1N*
#
# - Relación 1:N entre Software y Técnicas (todas las disponibles en MITRE). También incluye otras informaciones como tácticas, platform y data source. Campos: technique_id, technique, url_technique, software_id, software, software_description, software_type, url_software.
#     - [MITRE]_software_with_techniques_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Software y Técnicas (SÓLO DISPONIBLES EN CP). Campos: technique_id, technique, url_technique, software_id, software, software_description, software_type, url_software.
#     - [CP]_software_with_techniques_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Software y Técnicas (NO DISPONIBLES EN CP).  Campos: technique_id, technique, url_technique, software_id, software, software_description, software_type, url_software.
#     - [NOCP]_software_with_techniques_ddmmYY_hhmm_h.csv

# %% [markdown]
# <h3 style="background-color: #FF5733; color: black;">
#     5. GRUPOS - SOFTWARE
# </h3>
#
# #### 5.1 Tablas intermedias (1:N y N:N)
#
# Guardado en: *inter_groups_software*
#
# - Lista completa de software relacionados con los grupos. Campos: group_id, group, group_aliases, url_group, software_id, software, software_aliases, url_software.
#     - [MITRE]_n2n_groups_software_ddmmYY_hhmm_h.csv
#
# - Lista completa de software relacionados con los grupos filtrado por matriz enterprise. Campos: group_id, group, group_aliases, url_group, software_id, software, software_aliases, url_software.
#     - [MITRE]_n2n_enterprise_groups_software_ddmmYY_hhmm_h.csv
#
#
# #### 5.2 Grupo - Software (1:N)
#
# Guardado en: *group_software_1N*
#
# - Relación 1:N entre Grupo y Software (todas las disponibles en MITRE). Campos: group_id, group, group_aliases, url_group, software_id, software, software_aliases, url_software.
#     - [MITRE]_groups_with_software_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Grupo y Software (todas las disponibles en MITRE) filtrados por la matriz enterprise. Campos: group_id, group, group_aliases, url_group, software_id, software, software_aliases, url_software.
#     - [MITRE]_enterprise_groups_with_software_ddmmYY_hhmm_h.csv
#
#
# #### 5.3 Software - Grupo (1:N)
#
# Guardado en: *software_groups_1N*
#
# - Relación 1:N entre Software y Grupo (todas las disponibles en MITRE). Campos: group_id, group, group_aliases, url_group, software_id, software, software_aliases, url_software.
#     - [MITRE]_software_with_groups_ddmmYY_hhmm_h.csv
#
# - Relación 1:N entre Software y Grupo (todas las disponibles en MITRE) filtrados por la matriz enterprise. Campos: group_id, group, group_aliases, url_group, software_id, software, software_aliases, url_software.
#     - [MITRE]_enterprise_software_with_groups_ddmmYY_hhmm_h.csv

# %% [markdown]
# <h3 style="background-color: #FF5733; color: black;">
#     6. PLATAFORMAS - TÉCNICAS
# </h3>
#
# #### 6.1 Tablas intermedias ( N:N)
#
# Guardado en: *inter_techniques_platforms*
#
# - Lista completa de técnicas relacionadas con las plataformas (MITRE - enterprise). Campos: technique_id, technique, url_technique, platform.
#     - [MITRE]_n2n_enterprise_techniques_platforms_ddmmYY_hhmm_h.csv
#
# - Filtramos la lista completa por las técnicas disponibles en CP. Campos: technique_id, technique, url_technique, platform.
#     - [CP]_n2n_enterprise_techniques_platforms_ddmmYY_hhmm_h.csv
#
# - Filtramos la lista completa por las técnicas NO disponibles en CP. Campos: technique_id, technique, url_technique, platform.
#     - [NOCP]_n2n_enterprise_techniques_platforms_ddmmYY_hhmm_h.csv
#
#
# #### 6.2 Técnica - Plataformas (1:N)
#
# Guardado en: *technique_platforms_1N*
#
# - Relación 1:N entre Técnica y Plataformas (todas las disponibles en MITRE - enterprise). Campos: technique_id, technique, url_technique, platform.
#     - [MITRE]_enterprise_technique_with_platforms_ddmmYY_hhmm_h.csv
#
# - Filtramos la lista completa por las técnicas disponibles en CP. Campos: technique_id, technique, url_technique, platform.
#     - [CP]_enterprise_technique_with_platforms_ddmmYY_hhmm_h.csv
#
# - Filtramos la lista completa por las técnicas NO disponibles en CP. Campos: technique_id, technique, url_technique, platform.
#     - [NOCP]_enterprise_technique_with_platforms_ddmmYY_hhmm_h.csv
#
#
# #### 6.3 Plataforma - Técnicas (1:N)
#
# Guardado en: *platform_techniques_1N*
#
# - Relación 1:N entre Plataforma y Técnica (todas las disponibles en MITRE - enterprise). Campos: technique_id, technique, url_technique, platform.
#     - [MITRE]_enterprise_platform_with_techniques_ddmmYY_hhmm_h.csv
#
# - Filtramos la lista completa por las técnicas disponibles en CP. Campos: technique_id, technique, url_technique, platform.
#     - [CP]_enterprise_platform_with_techniques_ddmmYY_hhmm_h.csv
#
# - Filtramos la lista completa por las técnicas NO disponibles en CP. Campos: technique_id, technique, url_technique, platform.
#     - [NOCP]_enterprise_platform_with_techniques_ddmmYY_hhmm_h.csv

# %% [markdown]
# <h3 style="background-color: #FF5733; color: black;">
#     BONUS. GENERACIÓN LISTADO DE REGLAS DE DETECCIÓN POR TÉCNICA
# </h3>
#
#
# - Listado de reglas de deteccion disponibles en CyberProof asociadas a TTP's (incluyendo tambien las que no se han podido asignar a ninguna y por tanto se asignan a T0000)
#     - [CP]_ttp_rules_ddmmYY_hhmm_h.csv

# %% [markdown]
# #### Requerimientos

# %%
from attackcti import attack_client
import pandas as pd
import datetime
import csv
import os

from IPython.display import display
pd.options.display.max_columns = None

# %% [markdown]
# #### Funciones

# %%
def delete_special_characters(df):
    chars = r'[^\w\s,-.:]'  # Esto incluye cualquier cosa que no sea una palabra o espacio
    chars_url = r"[\[\]\'{}]"
    lb = r'\n'
    cr = r'\r'
    low_bar = r'_'
    colon_sep = r"': '"
    df = df.fillna('N/A')
    for col in df.columns:
        # Convertimos a str todas las columna
        if df[col].dtype == 'O':
            df[col] = df[col].astype(str)
        elif df[col].dtype == 'bool':
            df[col] = df[col].replace({True: 'True', False: 'False'})
        if col != 'external_references':
            # Aplicamos los reemplazos, importante mantener este orden
            df[col] = df[col].str.replace(colon_sep, ' - ', regex=True)
            df[col] = df[col].str.replace(low_bar, ' ', regex=True)
            df[col] = df[col].str.replace(chars, '', regex=True)
            df[col] = df[col].str.replace(lb, ' ', regex=True)
            df[col] = df[col].str.replace(cr, '', regex=True)
        else:
            df[col] = df[col].str.replace(chars_url, '', regex=True)
            df[col] = df[col].str.replace(colon_sep, ' - ', regex=True)
            df[col] = df[col].str.replace(low_bar, ' ', regex=True)
            df[col] = df[col].str.replace(lb, ' ', regex=True)
            df[col] = df[col].str.replace(cr, '', regex=True)
    return df

# %%
# Buscamos en la columna de descripción o informativa
def find_techniques(texto, techniques_enterprise_list):
    if isinstance(texto, str):
        found = []
        for item in techniques_enterprise_list:
            if item in texto:
                found.append(item)
        return ', '.join(found)
    else:
        return ''

# %%
def save_df_as_csv(df, name, aux_folder=''):
    now = datetime.datetime.now()
    if not os.path.exists(os.path.join(os.getcwd(), 'outputs', aux_folder)):
        os.makedirs(os.path.join(os.getcwd(), 'outputs', aux_folder))
    file_to_save = os.path.join(os.getcwd(), 'outputs', aux_folder, (name+ '_'+ now.strftime('%d%m%Y_%H%M')+'h.csv'))
    df.to_csv(file_to_save, sep=';', encoding='utf8', index=False, quoting=csv.QUOTE_NONNUMERIC)
    print('Fichero generado correctamente '+ name + '_' +now.strftime('%d%m%Y_%H%M')+'h.csv')

# %%
def getListOfFilesSub(dirName):
    # Crea lista de ficheros y subdirectorios
    listOfFile = os.listdir(dirName)
    allFiles = list()
    #Recorre los directorios y subdirectorios y genera una lista con los ficheros encontrados en estos
    for entry in listOfFile:
        fullPath = os.path.join(dirName, entry)
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFilesSub(fullPath)
        else:
            allFiles.append(fullPath)
    #Devuelve la lista con los ficheros
    return allFiles

# %%
# Función para quedarnos unicamente con items unicos al agregar
def unique_list(series):
    return list(set(series))

# %%
def cp_unique_ttp_with_rules(path):
    # Conjunto para almacenar nombres únicos de carpetas
    unique_folders = set()
    
    # Recorrer el directorio y sus subdirectorios
    for root, dirs, files in os.walk(path):
        for dir_name in dirs:
            # Verificar si el nombre de la carpeta contiene 'T0' o 'T1'
            if 'T0' in dir_name or 'T1' in dir_name:
                # Añadir solo el nombre de la carpeta al conjunto (esto elimina duplicados automáticamente)
                unique_folders.add(os.path.basename(dir_name))
    
    # Convertir el conjunto a una lista para el resultado final
    filtered_folders = list(unique_folders)
    filtered_folders = sorted(filtered_folders, key=len, reverse=True)
    filtered_folders.remove('T0000')
    
    return filtered_folders

# %%
def cp_ttps():
    ttps_outputs_path = r'C:\Users\jelopez\Documents\CyberProof\python\develop\download_ttps\saved'
    cp_ttp_available = cp_unique_ttp_with_rules(ttps_outputs_path)
    return cp_ttp_available

# %%
# El campo data_sources viene con un formato que no nos sirve para asociar el id y la url, por lo que lo formateamos dando lugar a 2 campos nuevos 
def split_lists(lst):
    if lst is None:
        return [], []
    before_colon = [item.split(': ')[0] for item in lst if item]
    after_colon = [item.split(': ')[1] for item in lst if item]
    return before_colon, after_colon

# %% [markdown]
# #### Métodos

# %%
lift = attack_client()

# %% [markdown]
# ##### get_enterprise_techniques

# %%
get_enterprise_techniques = lift.get_enterprise_techniques(stix_format=False)
get_enterprise_techniques_df = pd.json_normalize(get_enterprise_techniques)
get_enterprise_techniques_df = get_enterprise_techniques_df[(get_enterprise_techniques_df['mitre_deprecated'] != 'True')]
# Out:
# [taxii2client.v20] [WARNING ] [2024-07-02 09:47:18,461] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-07-02 09:47:18,532] TAXII Server Response with different amount of objects! Setting per_request=780

# %% [markdown]
# ##### get_enterprise_tactics

# %%
get_enterprise_tactics = lift.get_enterprise_tactics(stix_format=False)
get_enterprise_tactics_df = pd.json_normalize(get_enterprise_tactics)
get_enterprise_tactics_df = get_enterprise_tactics_df[(get_enterprise_tactics_df['mitre_deprecated'] != 'True')]
# Out:
# [taxii2client.v20] [WARNING ] [2024-06-19 17:17:48,530] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 17:17:48,530] TAXII Server Response with different amount of objects! Setting per_request=14

# %% [markdown]
# ##### get_data_sources

# %%
get_data_sources = lift.get_data_sources(stix_format=False)
get_data_sources_df = pd.json_normalize(get_data_sources)
# Out:
# [taxii2client.v20] [WARNING ] [2024-06-19 17:17:54,555] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 17:17:54,557] TAXII Server Response with different amount of objects! Setting per_request=38
# [taxii2client.v20] [WARNING ] [2024-06-19 17:18:02,507] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 17:18:02,507] TAXII Server Response with different amount of objects! Setting per_request=17
# [taxii2client.v20] [WARNING ] [2024-06-19 17:18:09,291] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 17:18:09,292] TAXII Server Response with different amount of objects! Setting per_request=6

# %% [markdown]
# ##### get_groups

# %%
get_groups = lift.get_groups(stix_format=False)
get_groups_df = pd.json_normalize(get_groups)
get_groups_df = get_groups_df.sort_values(by='group_id')
# Out:
# [taxii2client.v20] [WARNING ] [2024-06-19 17:18:21,429] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 17:18:21,429] TAXII Server Response with different amount of objects! Setting per_request=163
# [taxii2client.v20] [WARNING ] [2024-06-19 17:18:25,016] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 17:18:25,016] TAXII Server Response with different amount of objects! Setting per_request=13
# [taxii2client.v20] [WARNING ] [2024-06-19 17:18:38,376] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 17:18:38,377] TAXII Server Response with different amount of objects! Setting per_request=16

# %% [markdown]
# ##### get_techniques_used_by_all_groups()

# %%
get_techniques_used_by_all_groups = lift.get_techniques_used_by_all_groups(stix_format=False)
get_techniques_used_by_all_groups_df = pd.json_normalize(get_techniques_used_by_all_groups)
get_techniques_used_by_all_groups_df = get_techniques_used_by_all_groups_df.sort_values(by='group_id')

# %% [markdown]
# ##### get_software()

# %%
get_software = lift.get_software(stix_format=False)
get_software_df = pd.json_normalize(get_software)
get_software_df = get_software_df.sort_values(by='software_id')
# Out:
# [taxii2client.v20] [WARNING ] [2024-06-19 15:21:43,632] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 15:21:43,642] TAXII Server Response with different amount of objects! Setting per_request=595
# [taxii2client.v20] [WARNING ] [2024-06-19 15:21:50,315] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 15:21:50,315] TAXII Server Response with different amount of objects! Setting per_request=85
# [taxii2client.v20] [WARNING ] [2024-06-19 15:21:54,966] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 15:21:54,968] TAXII Server Response with different amount of objects! Setting per_request=111
# [taxii2client.v20] [WARNING ] [2024-06-19 15:22:02,260] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 15:22:02,260] TAXII Server Response with different amount of objects! Setting per_request=2
# [taxii2client.v20] [WARNING ] [2024-06-19 15:22:06,544] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-19 15:22:06,544] TAXII Server Response with different amount of objects! Setting per_request=28

# %% [markdown]
# #### Parámetros

# %%
save_to_file = True

# %% [markdown]
# ### **1. TÁCTICAS - TÉCNICAS**

# %% [markdown]
# #### **1.1 Tablas intermedias (N:N)**

# %%
# Comenzamos filtrando el df de técnicas y nos quedamos con las columnas que vamos a necesitar
enterprise_tactics_with_techniques_df = get_enterprise_techniques_df[['technique_id', 'technique','url','tactic']]
print(f"Filas del df: {enterprise_tactics_with_techniques_df.shape[0]}. TTP's únicas: {enterprise_tactics_with_techniques_df['technique_id'].nunique()}")
# Generamos tantas filas como tácticas encontremos dando lugar a una relación 1-1 entre técnicas y tácticas
enterprise_tactics_with_techniques_df = enterprise_tactics_with_techniques_df.explode('tactic')
print(f"Tras explode. Filas del df: {enterprise_tactics_with_techniques_df.shape[0]}. TTP's únicas: {enterprise_tactics_with_techniques_df['technique_id'].nunique()}. Tácticas únicas: {enterprise_tactics_with_techniques_df['tactic'].nunique()}")

# Reordenamos el df
enterprise_tactics_with_techniques_df = enterprise_tactics_with_techniques_df[['tactic', 'technique_id', 'technique', 'url']]
# Ordenamos por las tácticas
enterprise_tactics_with_techniques_df = enterprise_tactics_with_techniques_df.sort_values(by='tactic')
# Renombramos el campo url
enterprise_tactics_with_techniques_df = enterprise_tactics_with_techniques_df.rename(columns={'url': 'url_technique'})
# Llamamos a get_enterprise_tactics_df y nos quedamos con los campos que necesitamos para hacer left join
concat_get_enterprise_tactics_df = get_enterprise_tactics_df[['tactic_id','tactic_shortname','tactic_description','url']]
# Renombramos el campo url y tactic_shortname
concat_get_enterprise_tactics_df = concat_get_enterprise_tactics_df.rename(columns={'url': 'url_tactic', 'tactic_shortname': 'tactic'})
mitre_n2n_enterprise_techniques_tactics = pd.merge(enterprise_tactics_with_techniques_df, concat_get_enterprise_tactics_df, left_on='tactic', right_on='tactic', how='left')
mitre_n2n_enterprise_techniques_tactics.head(3)
print(f"Filas del df: {mitre_n2n_enterprise_techniques_tactics.shape[0]}. TTP's únicas: {mitre_n2n_enterprise_techniques_tactics['technique_id'].nunique()}. Tácticas únicas: {mitre_n2n_enterprise_techniques_tactics['tactic_id'].nunique()}")
# Out:
# Filas del df: 637. TTP's únicas: 637
# Tras explode. Filas del df: 830. TTP's únicas: 637. Tácticas únicas: 14
# Filas del df: 830. TTP's únicas: 637. Tácticas únicas: 14

# %% [markdown]
# **[MITRE] Técnicas - Tácticas (N:N)**

# %%
if save_to_file:
    save_df_as_csv(mitre_n2n_enterprise_techniques_tactics, '[MITRE]_enterprise_n2n_techniques_tactics', 'inter_techniques_tactics')
# Out:
# Fichero generado correctamente [MITRE]_enterprise_n2n_techniques_tactics

# %% [markdown]
# **[CP] Técnicas - Tácticas (N:N)**

# %%
cp_ttp_available = cp_ttps()
cp_n2n_enterprise_techniques_tactics = mitre_n2n_enterprise_techniques_tactics[mitre_n2n_enterprise_techniques_tactics['technique_id'].isin(cp_ttp_available)]
print(f"Filas del df: {cp_n2n_enterprise_techniques_tactics.shape[0]}. TTP's únicas: {cp_n2n_enterprise_techniques_tactics['technique_id'].nunique()}. Tácticas únicas: {cp_n2n_enterprise_techniques_tactics['tactic_id'].nunique()}")
if save_to_file:
    save_df_as_csv(cp_n2n_enterprise_techniques_tactics, '[CP]_enterprise_n2n_techniques_tactics', 'inter_techniques_tactics')
# Out:
# Filas del df: 679. TTP's únicas: 516. Tácticas únicas: 14

# %% [markdown]
# **[NOCP] Técnicas - Tácticas (N:N)**

# %%
nocp_n2n_enterprise_techniques_tactics = mitre_n2n_enterprise_techniques_tactics[~mitre_n2n_enterprise_techniques_tactics['technique_id'].isin(cp_ttp_available)]
print(f"Filas del df: {nocp_n2n_enterprise_techniques_tactics.shape[0]}. TTP's únicas: {nocp_n2n_enterprise_techniques_tactics['technique_id'].nunique()}. Tácticas únicas: {nocp_n2n_enterprise_techniques_tactics['tactic_id'].nunique()}")
if save_to_file:
    save_df_as_csv(nocp_n2n_enterprise_techniques_tactics, '[NOCP]_enterprise_n2n_techniques_tactics', 'inter_techniques_tactics')
# Out:
# Filas del df: 151. TTP's únicas: 121. Tácticas únicas: 13
# Fichero generado correctamente [NOCP]_enterprise_n2n_techniques_tactics

# %% [markdown]
# #### **1.2 Técnicas - Tácticas (1:N)**

# %% [markdown]
# **[MITRE] Técnicas - Tácticas (1:N)**

# %%
# Agregamos las columnas por la columna technique_id
mitre_techniques_with_tactics = mitre_n2n_enterprise_techniques_tactics.groupby('technique_id', as_index=False).agg({
    'technique':unique_list,
    'url_technique':unique_list,
    'tactic_id': unique_list,
    'tactic': unique_list,
    'tactic_description': unique_list,
    'url_tactic': unique_list
    })
if save_to_file:
    save_df_as_csv(mitre_techniques_with_tactics, '[MITRE]_techniques_with_tactics', 'technique_tactics_1N')
# Out:
# Fichero generado correctamente [MITRE]_techniques_with_tactics

# %% [markdown]
# **[CP] Técnicas - Tácticas (1:N)**

# %%
cp_techniques_with_tactics = cp_n2n_enterprise_techniques_tactics.groupby('technique_id', as_index=False).agg({
    'technique':unique_list,
    'url_technique':unique_list,
    'tactic_id': unique_list,
    'tactic': unique_list,
    'tactic_description': unique_list,
    'url_tactic': unique_list
    })
if save_to_file:
    save_df_as_csv(cp_techniques_with_tactics, '[CP]_techniques_with_tactics', 'technique_tactics_1N')
# Out:
# Fichero generado correctamente [CP]_techniques_with_tactics

# %% [markdown]
# **[NOCP] Técnicas - Tácticas (1:N)**

# %%
nocp_techniques_with_tactics = nocp_n2n_enterprise_techniques_tactics.groupby('technique_id', as_index=False).agg({
    'technique':unique_list,
    'url_technique':unique_list,
    'tactic_id': unique_list,
    'tactic': unique_list,
    'tactic_description': unique_list,
    'url_tactic': unique_list
    })
if save_to_file:
    save_df_as_csv(nocp_techniques_with_tactics, '[NOCP]_techniques_with_tactics', 'technique_tactics_1N')
# Out:
# Fichero generado correctamente [NOCP]_techniques_with_tactics

# %% [markdown]
# #### **1.3 Tácticas - Técnicas (1:N)**

# %% [markdown]
# **[MITRE] Tácticas - Técnicas (1:N)**

# %%
# Agregamos las columnas por la columna tactic_id
mitre_tactics_with_techniques = mitre_n2n_enterprise_techniques_tactics.groupby('tactic_id', as_index=False).agg({
    'tactic': unique_list,
    'tactic_description': unique_list,
    'url_tactic': unique_list,
    'technique_id': unique_list,
    'technique':unique_list,
    'url_technique':unique_list
    })

if save_to_file:
    save_df_as_csv(mitre_tactics_with_techniques, '[MITRE]_tactics_with_techniques', 'tactic_techniques_1N')
# Out:
# Fichero generado correctamente [MITRE]_tactics_with_techniques

# %% [markdown]
# **[CP] Tácticas - Técnicas (1:N)**

# %%
# Agregamos las columnas por la columna tactic_id
cp_tactics_with_techniques = cp_n2n_enterprise_techniques_tactics.groupby('tactic_id', as_index=False).agg({
    'tactic': unique_list,
    'tactic_description': unique_list,
    'url_tactic': unique_list,
    'technique_id': unique_list,
    'technique':unique_list,
    'url_technique':unique_list
    })

if save_to_file:
    save_df_as_csv(cp_tactics_with_techniques, '[CP]_tactics_with_techniques', 'tactic_techniques_1N')
# Out:
# Fichero generado correctamente [CP]_tactics_with_techniques

# %% [markdown]
# **[NOCP] Tácticas - Técnicas (1:N)**

# %%
# Agregamos las columnas por la columna tactic_id
nocp_tactics_with_techniques = nocp_n2n_enterprise_techniques_tactics.groupby('tactic_id', as_index=False).agg({
    'tactic': unique_list,
    'tactic_description': unique_list,
    'url_tactic': unique_list,
    'technique_id': unique_list,
    'technique':unique_list,
    'url_technique':unique_list
    })

if save_to_file:
    save_df_as_csv(nocp_tactics_with_techniques, '[NOCP]_tactics_with_techniques', 'tactic_techniques_1N')
# Out:
# Fichero generado correctamente [NOCP]_tactics_with_techniques

# %% [markdown]
# ### **2. DATA SOURCES - TÉCNICAS**

# %% [markdown]
# #### **2.1 Tablas intermedias (N:N)**

# %%
#Formateamos el df para exportar
data_sources_export_df = get_data_sources_df
data_sources_export_df['data_source_id'] = data_sources_export_df['url'].str.replace('https://attack.mitre.org/datasources/', '')
data_sources_export_df = data_sources_export_df[['data_source_id','data_source','data_source_description','url']].sort_values('data_source')
data_sources_export_df = data_sources_export_df.rename(columns={'url': 'url_data_source'})
if save_to_file:
    save_df_as_csv(data_sources_export_df, '[MITRE]_data_sources', 'inter_data_sources_techniques')
# Out:
# Fichero generado correctamente [MITRE]_data_sources

# %%
data_sources_export_df.head(3)
# Out:
#    data_source_id          data_source  \
# 8          DS0026     Active Directory
# 26         DS0015      Application Log
# 39         DS0041  Application Vetting
#
#                               data_source_description  \
# 8   A database and set of services that allows adm...
# 26  Events collected by third-party services such ...
# 39  Application vetting report generated by an ext...
#
#                                 url_data_source
# 8   https://attack.mitre.org/datasources/DS0026
# 26  https://attack.mitre.org/datasources/DS0015
# 39  https://attack.mitre.org/datasources/DS0041

# %%
# Obtenemos de get_enterprise_techniques_df las técnicas con el data source asociado
temp_o2n_techniques_data_sources_df = get_enterprise_techniques_df[['technique_id', 'data_sources','url']]
temp_o2n_techniques_data_sources_df = temp_o2n_techniques_data_sources_df.rename(columns={'url': 'url_technique'})

    
temp_o2n_techniques_data_sources_df[['data_source_simp', 'data_source_detail']] = temp_o2n_techniques_data_sources_df['data_sources'].apply(lambda x: pd.Series(split_lists(x)))
# Antes de unir las tablas debemos desagregar la tabla procendente de get_enterprise_techniques_df en tantas filas como tecnicas y data sources existan
n2n_techniques_data_sources_df = temp_o2n_techniques_data_sources_df.explode(['data_source_simp','data_source_detail'])
# Unimos las tablas para disponer de la información completa
n2n_techniques_data_sources_df = pd.merge(n2n_techniques_data_sources_df, data_sources_export_df, left_on='data_source_simp', right_on='data_source', how='outer') #left
n2n_techniques_data_sources_df = n2n_techniques_data_sources_df[['technique_id', 'url_technique', 'data_source_id', 'data_source', 'data_source_detail', 'url_data_source']]
#Eliminamos duplicados, no es necesario pero a futuro evitar inconsistencias
n2n_techniques_data_sources_df = n2n_techniques_data_sources_df.drop_duplicates()
#Ordenamos el df por la técnica
n2n_techniques_data_sources_df = n2n_techniques_data_sources_df.sort_values('technique_id')
n2n_techniques_data_sources_df.reset_index(drop=True, inplace=True)
n2n_techniques_data_sources_df.head(2)
# Out:
#   technique_id                                  url_technique data_source_id  \
# 0        T1001      https://attack.mitre.org/techniques/T1001         DS0029
# 1    T1001.001  https://attack.mitre.org/techniques/T1001/001         DS0029
#
#        data_source       data_source_detail  \
# 0  Network Traffic  Network Traffic Content
# 1  Network Traffic  Network Traffic Content
#
#                                url_data_source
# 0  https://attack.mitre.org/datasources/DS0029
# 1  https://attack.mitre.org/datasources/DS0029

# %%
ttps_without_sd_n2n_techniques_data_sources_df = n2n_techniques_data_sources_df[n2n_techniques_data_sources_df['data_source_id'].isnull()]
print(f"TTP's únicas sin data source asociado: {ttps_without_sd_n2n_techniques_data_sources_df['technique_id'].nunique()}")
ttps_with_sd_n2n_techniques_data_sources_df = n2n_techniques_data_sources_df[~n2n_techniques_data_sources_df['data_source_id'].isnull()]
print(f"TTP's únicas con data source asociado: {ttps_with_sd_n2n_techniques_data_sources_df['technique_id'].nunique()}")
sd_with_ttp_n2n_techniques_data_sources_df = n2n_techniques_data_sources_df[~n2n_techniques_data_sources_df['technique_id'].isnull()]
print(f"Data sources únicas con data source asociado: {sd_with_ttp_n2n_techniques_data_sources_df['data_source_id'].nunique()}")
sd_without_ttp_n2n_techniques_data_sources_df = n2n_techniques_data_sources_df[n2n_techniques_data_sources_df['technique_id'].isnull()]
print(f"Data sources únicas sin TTP asociada: {sd_without_ttp_n2n_techniques_data_sources_df['data_source_id'].nunique()}")
# Out:
# TTP's únicas sin data source asociado: 40
# TTP's únicas con data source asociado: 597
# Data sources únicas con data source asociado: 37
# Data sources únicas sin TTP asociada: 5

# %% [markdown]
# **[MITRE] Guardado Técnicas - Data sources N:N**

# %%
# Guardamos la relación entre técnicas y data sources completa: Técnicas con y sin data source; y Data sources con y sin técnica asociada.
if save_to_file:
    save_df_as_csv(n2n_techniques_data_sources_df, '[MITRE]_enterprise_n2n_all_techniques_data_sources', 'inter_data_sources_techniques')
# Out:
# Fichero generado correctamente [MITRE]_enterprise_n2n_all_techniques_data_sources

# %%
# Guardamos la relación entre técnicas y data sources completa: Sólo tecnicas y data sources con relación.
n2n_techniques_data_sources_df = n2n_techniques_data_sources_df[(~n2n_techniques_data_sources_df['technique_id'].isnull()) & (~n2n_techniques_data_sources_df['data_source_id'].isnull())]
if save_to_file:
    save_df_as_csv(n2n_techniques_data_sources_df, '[MITRE]_enterprise_n2n_techniques_data_sources', 'inter_data_sources_techniques')
# Out:
# Fichero generado correctamente [MITRE]_enterprise_n2n_techniques_data_sources

# %% [markdown]
# **[CP] Relación N:N Técnicas y Data Sources**
#
# Filtramos la tabla mitre por aquellas técnicas disponibles en CyberProof

# %%
cp_ttp_available = cp_ttps()
cp_ttp_available[:3]
# Out:
# ['T1195.001', 'T1021.007', 'T1052.001']

# %%
cp_n2n_techniques_data_sources_df = n2n_techniques_data_sources_df[n2n_techniques_data_sources_df['technique_id'].isin(cp_ttp_available)]
if save_to_file:
    save_df_as_csv(cp_n2n_techniques_data_sources_df, '[CP]_enterprise_n2n_techniques_data_sources', 'inter_data_sources_techniques')
# Out:
# Fichero generado correctamente [CP]_enterprise_n2n_techniques_data_sources

# %% [markdown]
# **[NOCP] Relación N:N Técnicas y Data Sources**

# %%
nocp_n2n_techniques_data_sources_df = n2n_techniques_data_sources_df[~n2n_techniques_data_sources_df['technique_id'].isin(cp_ttp_available)]
if save_to_file:
    save_df_as_csv(nocp_n2n_techniques_data_sources_df, '[NOCP]_enterprise_n2n_techniques_data_sources', 'inter_data_sources_techniques')
# Out:
# Fichero generado correctamente [NOCP]_enterprise_n2n_techniques_data_sources

# %% [markdown]
# #### **2.2 Técnicas - Data Sources (1:N)**

# %% [markdown]
# **[MITRE] TECHNIQUES - DATASOURCES 1:N**

# %%
# Agregamos las columnas por la columna technique_id
mitre_techniques_with_data_sources_df = n2n_techniques_data_sources_df.groupby('technique_id', as_index=False).agg({
    'url_technique':unique_list,
    'data_source_id': unique_list,
    'data_source': unique_list,
    'data_source_detail': unique_list,
    'url_data_source': unique_list
    })
if save_to_file:
    save_df_as_csv(mitre_techniques_with_data_sources_df, '[MITRE]_techniques_with_data_sources_df', 'technique_data_sources_1N')
# Out:
# Fichero generado correctamente [MITRE]_techniques_with_data_sources_df

# %% [markdown]
# **[CP] TECHNIQUES - DATASOURCES 1:N**

# %%
# Agregamos las columnas por la columna technique_id
cp_techniques_with_data_sources_df = cp_n2n_techniques_data_sources_df.groupby('technique_id', as_index=False).agg({
    'url_technique':unique_list,
    'data_source_id': unique_list,
    'data_source': unique_list,
    'data_source_detail': unique_list,
    'url_data_source': unique_list
    })
if save_to_file:
    save_df_as_csv(cp_techniques_with_data_sources_df, '[CP]_techniques_with_data_sources_df', 'technique_data_sources_1N')
# Out:
# Fichero generado correctamente [CP]_techniques_with_data_sources_df

# %% [markdown]
# **[NOCP] TECHNIQUES - DATASOURCES 1:N**

# %%
# Agregamos las columnas por la columna technique_id
nocp_techniques_with_data_sources_df = nocp_n2n_techniques_data_sources_df.groupby('technique_id', as_index=False).agg({
    'url_technique':unique_list,
    'data_source_id': unique_list,
    'data_source': unique_list,
    'data_source_detail': unique_list,
    'url_data_source': unique_list
    })
if save_to_file:
    save_df_as_csv(nocp_techniques_with_data_sources_df, '[NOCP]_techniques_with_data_sources_df', 'technique_data_sources_1N')
# Out:
# Fichero generado correctamente [NOCP]_techniques_with_data_sources_df

# %% [markdown]
# #### **2.3 Data Sources - Técnicas (1:N)**

# %% [markdown]
# **[MITRE] TECHNIQUES - DATASOURCES 1:N**

# %%
# Agregamos las columnas por la columna technique_id
mitre_data_source_with_techniques_df = n2n_techniques_data_sources_df.groupby('data_source_id', as_index=False).agg({
    'data_source': unique_list,
    'data_source_detail': unique_list,
    'url_data_source': unique_list,
    'url_technique':unique_list,
    'technique_id': unique_list
    })
save_df_as_csv(mitre_data_source_with_techniques_df, '[MITRE]_data_source_with_techniques', 'data_source_techniques_1N')
# Out:
# Fichero generado correctamente [MITRE]_data_source_with_techniques

# %% [markdown]
# **[CP] TECHNIQUES - DATA SOURCES 1:N**

# %%
# Agregamos las columnas por la columna technique_id
cp_data_source_with_techniques_df = cp_n2n_techniques_data_sources_df.groupby('data_source_id', as_index=False).agg({
    'data_source': unique_list,
    'data_source_detail': unique_list,
    'url_data_source': unique_list,
    'url_technique':unique_list,
    'technique_id': unique_list
    })
save_df_as_csv(cp_data_source_with_techniques_df, '[CP]_data_source_with_techniques', 'data_source_techniques_1N')
# Out:
# Fichero generado correctamente [CP]_data_source_with_techniques

# %% [markdown]
# **[NOCP] TECHNIQUES - DATA SOURCES 1:N**

# %%
# Agregamos las columnas por la columna technique_id
nocp_data_source_with_techniques_df = nocp_n2n_techniques_data_sources_df.groupby('data_source_id', as_index=False).agg({
    'data_source': unique_list,
    'data_source_detail': unique_list,
    'url_data_source': unique_list,
    'url_technique':unique_list,
    'technique_id': unique_list
    })
if save_to_file:
    save_df_as_csv(nocp_data_source_with_techniques_df, '[NOCP]_data_source_with_techniques', 'data_source_techniques_1N')
# Out:
# Fichero generado correctamente [NOCP]_data_source_with_techniques

# %% [markdown]
# ### **3. GRUPOS - TÉCNICAS**

# %% [markdown]
# #### **3.1 Tablas intermedias (N:N)**

# %%
groups_df = get_groups_df[['group_id','group','group_aliases','matrix','url']]
groups_df = groups_df.rename(columns={'url': 'url_group'})
if save_to_file:
    save_df_as_csv(groups_df, '[MITRE]_all_groups', 'inter_groups_techniques')
enterprise_groups_df = groups_df[groups_df['matrix'].apply(lambda x: 'enterprise-attack' in x)]
enterprise_groups_df.head(2)
if save_to_file:
    save_df_as_csv(enterprise_groups_df, '[MITRE]_enterprise_groups', 'inter_groups_techniques')
# Out:
# Fichero generado correctamente [MITRE]_all_groups_14062024_1432h.csv
# Fichero generado correctamente [MITRE]_enterprise_groups_14062024_1432h.csv

# %%
# OLD -> Se obtiene toda la información disponible (data source, platform, etc..) pero de cara a permitir correctamente las relaciones vamos a guardar sólo la información de técnicas y grupos
'''
# Filtramos los items cuya técnica sea de tipo enterprise. La lista de grupos se reduce al no aparecer aquellos con técnica asociada y ahora con tipo enterprise.
mitre_all_info_groups_df = get_techniques_used_by_all_groups_df[get_techniques_used_by_all_groups_df['technique_matrix'].apply(lambda x: 'enterprise-attack' in x)]
# Hacemos una selección de columnas con las que trabajar
mitre_all_info_groups_df = mitre_all_info_groups_df[['group_id','group','url','technique_id', 'technique', 'platform']]
# Renombramos la url de la técnica
mitre_all_info_groups_df = mitre_all_info_groups_df.rename(columns={'url': 'url_group'})

# Unimos con Data Sources para complementar la información
mitre_all_info_groups_df = pd.merge(mitre_all_info_groups_df, n2n_techniques_data_sources_df, left_on='technique_id', right_on='technique_id', how='left')
mitre_all_info_groups_df = mitre_all_info_groups_df.rename(columns={'url_technique_x': 'url_technique'})

# Ampliamos el df por todos los campos necesarios para llegar a la relación N:N con el detalle de los data sources
mitre_all_info_groups_df = mitre_all_info_groups_df.explode(['data_source','data_source_detail'])

# Unimos con Tácticas para complementar la información
# Importante: No hemos añadido la información de tácticas que se facilita en get_techniques_used_by_all_groups ya que queremos hacer un left join limpio directamente con technique_id
mitre_all_info_groups_df = pd.merge(mitre_all_info_groups_df, mitre_n2n_enterprise_techniques_tactics, left_on='technique_id', right_on='technique_id', how='left')


# Al realizar la unión de tácticas con técnicas se crearan más filas ya que cada técnica puede estar asociada a varias tácticas. Reemplazamos el nombre de algunas columnas generadas y eliminamos las duplicadas. 
mitre_all_info_groups_df = mitre_all_info_groups_df.rename(columns={'technique_x': 'technique','url_technique_x': 'url_technique'})
mitre_all_info_groups_df.drop('technique_y', axis=1, inplace=True)
mitre_all_info_groups_df.drop('url_technique_y', axis=1, inplace=True)
mitre_all_info_groups_df = mitre_all_info_groups_df.explode(['platform'])

print(f"Filas del df: {mitre_all_info_groups_df.shape[0]}.  Grupos unicos: {mitre_all_info_groups_df['group_id'].nunique()}. TTP's únicas: {mitre_all_info_groups_df['technique_id'].nunique()}. Platform únicas: {mitre_all_info_groups_df['platform'].nunique()}. Tácticas únicas: {mitre_all_info_groups_df['data_source'].nunique()}. Data Sources únicos: {mitre_all_info_groups_df['data_source'].nunique()}")

'''
# Out:
# '\n# Filtramos los items cuya técnica sea de tipo enterprise. La lista de grupos se reduce al no aparecer aquellos con técnica asociada y ahora con tipo enterprise.\nmitre_all_info_groups_df = get_techniques_used_by_all_groups_df[get_techniques_used_by_all_groups_df[\'technique_matrix\'].apply(lambda x: \'enterprise-attack\' in x)]\n# Hacemos una selección de columnas con las que trabajar\nmitre_all_info_groups_df = mitre_all_info_groups_df[[\'group_id\',\'group\',\'url\',\'technique_id\', \'technique\', \'platform\']]\n# Renombramos la url de la técnica\nmitre_all_info_groups_df = mitre_all_info_groups_df.rename(columns={\'url\': \'url_group\'})\n\n# Unimos con Data Sources para complementar la información\nmitre_all_info_groups_df = pd.merge(mitre_all_info_groups_df, n2n_techniques_data_sources_df, left_on=\'technique_id\', right_on=\'technique_id\', how=\'left\')\nmitre_all_info_groups_df = mitre_all_info_groups_df.rename(columns={\'url_technique_x\': \'url_technique\'})\n\n# Ampliamos el df por todos los campos necesarios para llegar a la relación N:N con el detalle de los data sources\nmitre_all_info_groups_df = mitre_all_info_groups_df.explode([\'data_source\',\'data_source_detail\'])\n\n# Unimos con Tácticas para complementar la información\n# Importante: No hemos añadido la información de tácticas que se facilita en get_techniques_used_by_all_groups ya que queremos hacer un left join limpio directamente con technique_id\nmitre_all_info_groups_df = pd.merge(mitre_all_info_groups_df, mitre_n2n_enterprise_techniques_tactics, left_on=\'technique_id\', right_on=\'technique_id\', how=\'left\')\n\n\n# Al realizar la unión de tácticas con técnicas se crearan más filas ya que cada técnica puede estar asociada a varias tácticas. Reemplazamos el nombre de algunas columnas generadas y eliminamos las duplicadas. \nmitre_all_info_groups_df = mitre_all_info_groups_df.rename(columns={\'technique_x\': \'technique\',\'url_technique_x\': \'url_technique\'})\nmitre_all_info_groups_df.drop(\'technique_y\', axis=1, inplace=True)\nmitre_all_info_groups_df.drop(\'url_technique_y\', axis=1, inplace=True)\nmitre_all_info_groups_df = mitre_all_info_groups_df.explode([\'platform\'])\n\nprint(f"Filas del df: {mitre_all_info_groups_df.shape[0]}.  Grupos unicos: {mitre_all_info_groups_df[\'group_id\'].nunique()}. TTP\'s únicas: {mitre_all_info_groups_df[\'technique_id\'].nunique()}. Platform únicas: {mitre_all_info_groups_df[\'platform\'].nunique()}. Tácticas únicas: {mitre_all_info_groups_df[\'data_source\'].nunique()}. Data Sources únicos: {mitre_all_info_groups_df[\'data_source\'].nunique()}")\n\n'

# %%
# Filtramos los items cuya técnica sea de tipo enterprise. La lista de grupos se reduce al no aparecer aquellos con técnica asociada y ahora con tipo enterprise.
mitre_n2n_techniques_groups_df = get_techniques_used_by_all_groups_df[get_techniques_used_by_all_groups_df['technique_matrix'].apply(lambda x: 'enterprise-attack' in x)]
# Hacemos una selección de columnas con las que trabajar
mitre_n2n_techniques_groups_df = mitre_n2n_techniques_groups_df[['group_id','group','url','technique_id', 'technique']]
# Renombramos la url de la técnica
mitre_n2n_techniques_groups_df = mitre_n2n_techniques_groups_df.rename(columns={'url': 'url_group'})

#Unimos con la tabla de técnicas para completar la información relativa a estas
mitre_n2n_techniques_groups_df = pd.merge(mitre_n2n_techniques_groups_df, get_enterprise_techniques_df[['technique_id', 'technique','url']], left_on='technique_id', right_on='technique_id', how='left')

# Renombramos la url de la técnica
mitre_n2n_techniques_groups_df = mitre_n2n_techniques_groups_df.rename(columns={'technique_x': 'technique','url': 'url_technique'})
# Eliminamos la columna sobrante
mitre_n2n_techniques_groups_df.drop('technique_y', axis=1, inplace=True)

print(f"Filas del df: {mitre_n2n_techniques_groups_df.shape[0]}.  Grupos unicos: {mitre_n2n_techniques_groups_df['group_id'].nunique()}. TTP's únicas: {mitre_n2n_techniques_groups_df['technique_id'].nunique()}")

mitre_n2n_techniques_groups_df.head(2)
# Out:
# Filas del df: 3387.  Grupos unicos: 143. TTP's únicas: 421
#   group_id  group                              url_group technique_id  \
# 0    G0001  Axiom  https://attack.mitre.org/groups/G0001        T1560
# 1    G0001  Axiom  https://attack.mitre.org/groups/G0001    T1583.002
#
#                 technique                                  url_technique
# 0  Archive Collected Data      https://attack.mitre.org/techniques/T1560
# 1              DNS Server  https://attack.mitre.org/techniques/T1583/002

# %% [markdown]
# **[MITRE] Guardado Grupos - Técnicas N:N**

# %%
if save_to_file:
    save_df_as_csv(mitre_n2n_techniques_groups_df, '[MITRE]_enterprise_techniques_groups', 'inter_groups_techniques')
# Out:
# Fichero generado correctamente [MITRE]_enterprise_techniques_groups_14062024_1433h.csv

# %% [markdown]
# **[CP] Relación Grupos - Técnicas N:N**

# %%
cp_ttp_available = cp_ttps()
cp_n2n_techniques_groups_df = mitre_n2n_techniques_groups_df[mitre_n2n_techniques_groups_df['technique_id'].isin(cp_ttp_available)]
print(f"Filas del df: {cp_n2n_techniques_groups_df.shape[0]}. Grupos únicos: {cp_n2n_techniques_groups_df['group_id'].nunique()}. TTP's únicas: {cp_n2n_techniques_groups_df['technique_id'].nunique()}")
if save_to_file:
    save_df_as_csv(cp_n2n_techniques_groups_df, '[CP]_enterprise_techniques_groups', 'inter_groups_techniques')
# Out:
# Filas del df: 3150. Grupos únicos: 142. TTP's únicas: 363
# Fichero generado correctamente [CP]_enterprise_techniques_groups_14062024_1434h.csv

# %% [markdown]
# **[NOCP] Relación Grupos - Técnicas N:N**

# %%
cp_ttp_available = cp_ttps()
nocp_n2n_techniques_groups_df = mitre_n2n_techniques_groups_df[~mitre_n2n_techniques_groups_df['technique_id'].isin(cp_ttp_available)]
print(f"Filas del df: {nocp_n2n_techniques_groups_df.shape[0]}. Grupos únicos: {nocp_n2n_techniques_groups_df['group_id'].nunique()}. TTP's únicas: {nocp_n2n_techniques_groups_df['technique_id'].nunique()}")
if save_to_file:
    save_df_as_csv(nocp_n2n_techniques_groups_df, '[NOCP]_enterprise_techniques_groups', 'inter_groups_techniques')
# Out:
# Filas del df: 237. Grupos únicos: 83. TTP's únicas: 58
# Fichero generado correctamente [NOCP]_enterprise_techniques_groups_14062024_1434h.csv

# %% [markdown]
# #### **3.2 Grupos - Técnicas (1:N)**

# %% [markdown]
# **[MITRE] Grupos - Técnicas (1:N)**

# %%
# Agregamos las columnas por la columna group_id
mitre_groups_with_techniques_df = mitre_n2n_techniques_groups_df.groupby('group_id', as_index=False).agg({
    'group':unique_list,
    'url_group':unique_list,
    'technique_id': unique_list,
    'technique': unique_list,
    'url_technique': unique_list
    })
if save_to_file:
    save_df_as_csv(mitre_groups_with_techniques_df, '[MITRE]_groups_with_techniques', 'group_techniques_1N')

mitre_groups_with_techniques_df.head(2)
# Out:
# Fichero generado correctamente [MITRE]_groups_with_techniques_14062024_1434h.csv
#   group_id     group                                url_group  \
# 0    G0001   [Axiom]  [https://attack.mitre.org/groups/G0001]
# 1    G0002  [Moafee]  [https://attack.mitre.org/groups/G0002]
#
#                                         technique_id  \
# 0  [T1001.002, T1005, T1560, T1553, T1546.008, T1...
# 1                                        [T1027.001]
#
#                                            technique  \
# 0  [Virtual Private Server, Steganography, Subver...
# 1                                   [Binary Padding]
#
#                                        url_technique
# 0  [https://attack.mitre.org/techniques/T1584/005...
# 1    [https://attack.mitre.org/techniques/T1027/001]

# %%
print(f"[MITRE] Filas del df: {mitre_groups_with_techniques_df.shape[0]}. Grupos únicos: {mitre_groups_with_techniques_df['group_id'].nunique()}.")
# Out:
# [MITRE] Filas del df: 143. Grupos únicos: 143.

# %% [markdown]
# **[CP] Grupos - Técnicas (1:N)**

# %%
# Agregamos las columnas por la columna group_id
cp_groups_with_techniques_df = cp_n2n_techniques_groups_df.groupby('group_id', as_index=False).agg({
    'group':unique_list,
    'url_group':unique_list,
    'technique_id': unique_list,
    'technique': unique_list,
    'url_technique': unique_list
    })
if save_to_file:
    save_df_as_csv(cp_groups_with_techniques_df, '[CP]_groups_with_techniques', 'group_techniques_1N')

cp_groups_with_techniques_df.head(2)
# Out:
# Fichero generado correctamente [CP]_groups_with_techniques_14062024_1434h.csv
#   group_id     group                                url_group  \
# 0    G0001   [Axiom]  [https://attack.mitre.org/groups/G0001]
# 1    G0002  [Moafee]  [https://attack.mitre.org/groups/G0002]
#
#                                         technique_id  \
# 0  [T1001.002, T1005, T1560, T1553, T1546.008, T1...
# 1                                        [T1027.001]
#
#                                            technique  \
# 0  [Steganography, Subvert Trust Controls, Data f...
# 1                                   [Binary Padding]
#
#                                        url_technique
# 0  [https://attack.mitre.org/techniques/T1560, ht...
# 1    [https://attack.mitre.org/techniques/T1027/001]

# %%
print(f"[CP] Filas del df: {cp_groups_with_techniques_df.shape[0]}. Grupos únicos: {cp_groups_with_techniques_df['group_id'].nunique()}.")
# Out:
# [CP] Filas del df: 142. Grupos únicos: 142.

# %% [markdown]
# **[NOCP] Grupos - Técnicas (1:N)**

# %%
# Agregamos las columnas por la columna group_id
nocp_groups_with_techniques_df = nocp_n2n_techniques_groups_df.groupby('group_id', as_index=False).agg({
    'group':unique_list,
    'url_group':unique_list,
    'technique_id': unique_list,
    'technique': unique_list,
    'url_technique': unique_list
    })
if save_to_file:
    save_df_as_csv(nocp_groups_with_techniques_df, '[NOCP]_groups_with_techniques', 'group_techniques_1N')

nocp_groups_with_techniques_df.head(2)
# Out:
# Fichero generado correctamente [NOCP]_groups_with_techniques_14062024_1434h.csv
#   group_id      group                                url_group  \
# 0    G0001    [Axiom]  [https://attack.mitre.org/groups/G0001]
# 1    G0003  [Cleaver]  [https://attack.mitre.org/groups/G0003]
#
#                         technique_id  \
# 0  [T1583.003, T1583.002, T1584.005]
# 1                        [T1585.001]
#
#                                       technique  \
# 0  [Virtual Private Server, Botnet, DNS Server]
# 1                       [Social Media Accounts]
#
#                                        url_technique
# 0  [https://attack.mitre.org/techniques/T1584/005...
# 1    [https://attack.mitre.org/techniques/T1585/001]

# %%
print(f"[NOCP] Filas del df: {nocp_groups_with_techniques_df.shape[0]}. Grupos únicos: {nocp_groups_with_techniques_df['group_id'].nunique()}.")
# Out:
# [NOCP] Filas del df: 83. Grupos únicos: 83.

# %% [markdown]
# #### **3.3 Técnicas - Grupos (1:N)**

# %% [markdown]
# **[MITRE] Técnicas - Grupos (1:N)**

# %%
# Agregamos las columnas por la columna technique_id
mitre_techniques_with_groups_df = mitre_n2n_techniques_groups_df.groupby('technique_id', as_index=False).agg({
    'technique': unique_list,
    'url_technique': unique_list,
    'group':unique_list,
    'group_id':unique_list,
    'url_group':unique_list
    })
if save_to_file:
    save_df_as_csv(mitre_techniques_with_groups_df, '[MITRE]_techniques_with_groups_df', 'technique_groups_1N')

mitre_techniques_with_groups_df.head(2)
# Out:
# Fichero generado correctamente [MITRE]_techniques_with_groups_df_14062024_1434h.csv
#   technique_id        technique  \
# 0    T1001.001      [Junk Data]
# 1    T1001.002  [Steganography]
#
#                                      url_technique    group group_id  \
# 0  [https://attack.mitre.org/techniques/T1001/001]  [APT28]  [G0007]
# 1  [https://attack.mitre.org/techniques/T1001/002]  [Axiom]  [G0001]
#
#                                  url_group
# 0  [https://attack.mitre.org/groups/G0007]
# 1  [https://attack.mitre.org/groups/G0001]

# %%
print(f"[MITRE] Filas del df: {mitre_techniques_with_groups_df.shape[0]}. TTP's únicas: {mitre_techniques_with_groups_df['technique_id'].nunique()}.")
# Out:
# [MITRE] Filas del df: 421. TTP's únicas: 421.

# %% [markdown]
# **[CP] Técnicas - Grupos (1:N)**

# %%
# Agregamos las columnas por la columna technique_id
cp_techniques_with_groups_df = cp_n2n_techniques_groups_df.groupby('technique_id', as_index=False).agg({
    'technique': unique_list,
    'url_technique': unique_list,
    'group':unique_list,
    'group_id':unique_list,
    'url_group':unique_list
    })
if save_to_file:
    save_df_as_csv(cp_techniques_with_groups_df, '[CP]_techniques_with_groups_df', 'technique_groups_1N')

cp_techniques_with_groups_df.head(2)
# Out:
# Fichero generado correctamente [CP]_techniques_with_groups_df_14062024_1434h.csv
#   technique_id                 technique  \
# 0    T1001.002           [Steganography]
# 1    T1001.003  [Protocol Impersonation]
#
#                                      url_technique                     group  \
# 0  [https://attack.mitre.org/techniques/T1001/002]                   [Axiom]
# 1  [https://attack.mitre.org/techniques/T1001/003]  [Lazarus Group, Higaisa]
#
#          group_id                                          url_group
# 0         [G0001]            [https://attack.mitre.org/groups/G0001]
# 1  [G0032, G0126]  [https://attack.mitre.org/groups/G0032, https:...

# %%
print(f"[CP] Filas del df: {cp_techniques_with_groups_df.shape[0]}. TTP's únicas: {cp_techniques_with_groups_df['technique_id'].nunique()}.")
# Out:
# [CP] Filas del df: 363. TTP's únicas: 363.

# %% [markdown]
# **[NOCP] Técnicas - Grupos (1:N)**

# %%
# Agregamos las columnas por la columna technique_id
nocp_techniques_with_groups_df = nocp_n2n_techniques_groups_df.groupby('technique_id', as_index=False).agg({
    'technique': unique_list,
    'url_technique': unique_list,
    'group':unique_list,
    'group_id':unique_list,
    'url_group':unique_list
    })
if save_to_file:
    save_df_as_csv(nocp_techniques_with_groups_df, '[NOCP]_techniques_with_groups_df', 'technique_groups_1N')

nocp_techniques_with_groups_df.head(2)
# Out:
# Fichero generado correctamente [NOCP]_techniques_with_groups_df_14062024_1435h.csv
#   technique_id          technique  \
# 0    T1001.001        [Junk Data]
# 1    T1016.002  [Wi-Fi Discovery]
#
#                                      url_technique          group group_id  \
# 0  [https://attack.mitre.org/techniques/T1001/001]        [APT28]  [G0007]
# 1  [https://attack.mitre.org/techniques/T1016/002]  [Magic Hound]  [G0059]
#
#                                  url_group
# 0  [https://attack.mitre.org/groups/G0007]
# 1  [https://attack.mitre.org/groups/G0059]

# %%
print(f"[NOCP] Filas del df: {nocp_techniques_with_groups_df.shape[0]}. TTP's únicas: {nocp_techniques_with_groups_df['technique_id'].nunique()}.")
# Out:
# [NOCP] Filas del df: 58. TTP's únicas: 58.

# %% [markdown]
# ### **4. SOFTWARE - TÉCNICAS**

# %% [markdown]
# #### **4.1 Tablas intermedias (N:N)**

# %%
software_df = get_software_df[['software_id','software','software_aliases','type','url','matrix']]
software_df = software_df.rename(columns={'url': 'url_software'})
if save_to_file:
    save_df_as_csv(software_df, '[MITRE]_all_software', 'inter_software_techniques')
enterprise_software_df = software_df[software_df['matrix'].apply(lambda x: 'enterprise-attack' in x)]
enterprise_software_df.head(2)
if save_to_file:
    save_df_as_csv(enterprise_software_df, '[MITRE]_enterprise_software', 'inter_software_techniques')
# Out:
# Fichero generado correctamente [MITRE]_all_software
# Fichero generado correctamente [MITRE]_enterprise_software

# %% [markdown]
# PROBLEMA: No soy capaz de relacionar software con técnica.
#
# get_techniques_used_by_software -> NO trae ninguna columna con la que poder identificar el software
#
# get_enterprise_malware, get_enterprise_tools -> Atacando a través de la tipologia del software tampoco soy capaz de identificar ninguna relación
#
# Solución: Tras probar directamente a stix y otras opciones he encontrado el método get_techniques_used_by_software(), al cual si se le pasa el objeto stix2.v20.sdo.Tool correspondiente como unico software del metodo get_software() como parametro este devolverá la tabla con las técnicas asociadas. Por lo tanto, mediante un bucle iremos recorriendo la lista de software (794) y se iran añadiendo a un df donde ademas de las técnicas incorporaremos la información relativa al SW.

# %%
results_df = pd.DataFrame(columns=['type', 'id', 'url', 'matrix', 'created', 'modified', 'created_by_ref',
       'modified_by_ref', 'external_references', 'object_marking_refs',
       'mitre_version', 'mitre_attack_spec_version', 'mitre_deprecated',
       'technique', 'technique_id', 'technique_description', 'tactic',
       'technique_detection', 'platform', 'data_sources', 'defense_bypassed',
       'permissions_required', 'effective_permissions', 'system_requirements',
       'network_requirements', 'remote_support', 'contributors', 'tactic_type',
       'impact_type', 'is_subtechnique', 'software_id', 'software',
       'software_aliases', 'software_description', 'software_type',
       'url_software', 'mitre_domains'])

# %%
# En esta parte del código obtenemos la lista de software y uno a uno se lo pasamos al método et_techniques_used_by_software que nos devolverá la tabla con las técnicas utilizadas por cada SW.
# Importante: Este código es lento, aproximadamente tarda 1,5 minutos por petición lo que hace que para los 795 items tarde aproximadamente 20 horas.
# Si se tiene que reejecutar esta parte tambien es posible que falle alguna conexión, en tal caso en lugar de empezar de 0 simplemente no ejecutar la celda anterior y modificar range(len(software)) por range(row, len(software))

software = lift.get_software()

for row in range(len(software)):

    info_row_techniques_software =  lift.get_techniques_used_by_software(software[row], stix_format=False)
    info_row_techniques_software_df = pd.json_normalize(info_row_techniques_software)


    # Recogemos info de software y la añadimos al df
    info_row_techniques_software_df['software_id'] = software[row].external_references[0].external_id

    info_row_techniques_software_df['software'] = software[row].name

    aliases = getattr(software[row], 'x_mitre_aliases', [])
    info_row_techniques_software_df['software_aliases'] = [aliases] * len(info_row_techniques_software_df)

    info_row_techniques_software_df['software_description'] = software[row].description

    info_row_techniques_software_df['software_type'] = software[row].type

    info_row_techniques_software_df['url_software'] = software[row].external_references[0].url
    
    domains = getattr(software[row], 'x_mitre_domains', [])
    info_row_techniques_software_df['mitre_domains'] = [domains] * len(info_row_techniques_software_df)

    print(f"Finalizado {row}: {software[row].name}")


    results_df = pd.concat([results_df,info_row_techniques_software_df])
# Filtramos técnicas deprecadas
results_df = results_df[(results_df['mitre_deprecated'] != 'True')]
# Filtramos SW enterprise
results_df = results_df[results_df['mitre_domains'].apply(lambda x: 'enterprise-attack' in x)]

results_df['url_technique'] = results_df['external_references'].apply(lambda x: x[0]['url'] if x else None)

if save_to_file:
    save_df_as_csv(results_df, '[MITRE]_n2n_main_techniques_software', 'inter_software_techniques')
# Out:
# [taxii2client.v20] [WARNING ] [2024-06-14 09:29:57,827] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:07,079] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:08,397] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:12,602] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:17,020] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:17,058] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:20,540] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:20,557] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:23,791] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:23,817] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:26,930] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:26,945] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:29,948] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:29,948] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 648: FLASHFLOOD
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:36,870] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:40,590] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:46,278] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:53,951] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:57,621] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:30:57,637] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:00,606] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:00,623] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:06,445] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:06,461] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:10,532] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:10,532] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:13,538] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:13,538] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 649: SPACESHIP
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:17,570] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:19,307] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:21,357] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:23,977] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:30,314] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:30,331] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:35,853] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:35,874] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:44,143] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:44,165] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:47,462] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:47,462] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:50,697] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:31:50,698] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 650: NETEAGLE
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:01,279] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:13,867] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:19,438] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:20,589] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:27,695] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:27,713] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:30,881] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:30,898] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:34,980] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:35,004] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:37,858] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:37,858] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:41,907] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:41,907] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 651: NetTraveler
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:46,494] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:53,517] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:32:57,837] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:00,106] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:06,227] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:06,248] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:09,548] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:09,563] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:15,401] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:15,436] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:18,454] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:18,454] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:21,690] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:21,707] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 652: gh0st RAT
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:25,977] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:28,796] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:30,964] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:32,983] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:38,819] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:38,822] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:44,976] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:44,991] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:48,879] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:48,917] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:51,664] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:51,665] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:54,517] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:54,517] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 653: BACKSPACE
# [taxii2client.v20] [WARNING ] [2024-06-14 09:33:59,538] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:01,810] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:04,092] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:05,221] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:08,362] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:08,379] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:11,314] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:11,331] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:23,091] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:23,129] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:26,744] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:26,761] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:34,734] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:34,750] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 654: Carbanak
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:45,693] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:34:56,535] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:07,544] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:11,665] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:16,989] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:17,002] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:20,121] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:20,121] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:23,608] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:23,645] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:31,067] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:31,080] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:35,268] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:35,268] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 655: SHIPSHAPE
# [taxii2client.v20] [WARNING ] [2024-06-14 09:35:55,584] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:36:25,365] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:36:45,259] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:36:55,693] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:37:02,207] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:37:02,245] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:37:10,171] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:37:10,190] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:37:25,342] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:37:25,516] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:37:30,045] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:37:30,046] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:37:35,750] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:37:35,750] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 656: Zeroaccess
# [taxii2client.v20] [WARNING ] [2024-06-14 09:37:45,734] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:00,235] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:16,373] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:20,788] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:23,826] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:23,862] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:26,859] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:26,876] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:30,029] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:30,079] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:33,198] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:33,213] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:35,868] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:35,870] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 657: GLOOXMAIL
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:45,208] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:48,828] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:52,247] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:54,515] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:57,618] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:38:57,635] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:00,804] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:00,824] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:05,099] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:05,108] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:08,747] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:08,760] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:11,279] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:11,295] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 658: CALENDAR
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:15,414] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:17,001] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:18,490] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:19,969] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:23,240] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:23,259] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:26,441] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:26,457] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:29,798] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:29,835] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:32,521] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:32,526] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:35,751] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:35,767] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 659: Dyre
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:41,957] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:43,476] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:45,076] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:47,128] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:50,345] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:50,364] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:53,331] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:53,350] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:57,069] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:39:57,106] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:00,006] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:00,006] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:03,089] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:03,089] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 660: CHOPSTICK
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:07,209] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:09,344] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:11,231] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:14,115] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:18,188] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:18,202] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:22,755] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:22,755] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:27,150] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:27,176] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:30,365] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:30,365] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:35,886] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:35,886] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 661: Uroburos
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:45,314] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:48,395] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:52,799] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:40:55,866] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:02,105] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:02,120] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:07,928] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:07,943] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:13,698] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:13,718] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:17,703] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:17,703] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:24,074] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:24,074] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 662: Derusbi
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:29,912] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:36,233] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:42,490] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:48,160] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:53,499] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:41:53,524] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:05,193] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:05,213] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:13,514] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:13,532] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:16,610] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:16,614] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:20,119] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:20,119] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 663: China Chopper
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:33,899] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:39,937] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:50,863] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:56,367] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:59,887] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:42:59,923] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:03,191] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:03,205] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:09,643] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:09,680] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:12,297] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:12,314] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:16,082] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:16,099] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 664: Regin
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:24,488] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:31,644] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:37,078] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:40,946] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:44,110] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:44,126] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:47,241] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:47,266] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:54,397] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:43:54,420] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:01,203] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:01,203] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:06,023] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:06,023] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 665: Sykipot
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:17,344] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:22,019] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:30,679] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:32,929] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:39,854] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:39,868] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:45,324] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:45,335] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:53,196] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:53,216] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:57,800] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:44:57,800] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:04,539] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:04,539] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 666: BISCUIT
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:10,537] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:13,962] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:16,582] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:18,684] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:21,630] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:21,645] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:24,946] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:24,946] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:32,060] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:32,091] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:35,422] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:35,422] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:38,909] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:38,911] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 667: P2P ZeuS
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:44,822] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:45:58,832] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:03,827] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:10,776] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:16,343] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:16,359] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:27,110] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:27,124] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:31,944] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:31,979] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:35,282] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:35,282] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:39,202] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:39,219] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 668: Ixeshe
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:49,194] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:46:58,065] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:09,959] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:15,180] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:25,521] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:25,538] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:29,125] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:29,125] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:40,441] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:40,471] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:44,004] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:44,004] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:46,873] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:46,873] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 669: BS2005
# [taxii2client.v20] [WARNING ] [2024-06-14 09:47:53,747] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:01,605] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:09,882] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:12,477] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:16,364] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:16,383] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:19,787] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:19,800] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:23,737] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:23,775] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:27,727] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:27,727] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:30,778] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:30,778] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 670: PlugX
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:36,549] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:41,637] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:48,957] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:48:59,469] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:49:08,126] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 09:49:08,161] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 09:49:13,711] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# ...
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:28,273] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:32,226] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:32,241] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:35,661] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:35,677] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:38,646] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:38,663] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:41,263] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:41,268] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:44,334] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:44,334] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 786: Dendroid
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:48,905] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:50,590] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:52,091] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:52,942] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:56,076] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:56,244] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:59,180] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:43:59,199] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:03,283] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:03,305] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:06,482] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:06,486] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:11,070] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:11,073] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 787: WireLurker
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:15,127] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:16,944] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:18,446] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:21,099] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:24,869] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:24,885] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:28,256] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:28,270] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:31,574] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:31,590] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:34,211] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:34,225] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:37,412] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:37,412] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 788: NotCompatible
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:41,466] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:44,866] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:47,673] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:51,373] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:55,212] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:55,226] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:58,546] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:44:58,563] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:04,383] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:04,401] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:07,903] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:07,903] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:10,906] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:10,906] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 789: INCONTROLLER
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:14,826] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:16,760] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:18,645] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:20,515] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:24,904] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:24,919] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:29,319] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:29,340] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:34,725] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:34,758] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:37,962] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:37,978] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:42,166] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:42,166] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 790: VPNFilter
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:51,289] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:56,794] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:45:59,813] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:01,731] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:04,936] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:04,965] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:10,103] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:10,125] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:13,373] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:13,391] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:16,115] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:16,118] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:19,296] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:19,296] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 791: Triton
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:36,058] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:40,397] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:46,702] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:50,507] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:56,521] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:46:56,527] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:04,920] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:04,933] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:14,624] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:14,660] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:17,515] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:17,520] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:20,464] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:20,464] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 792: PLC-Blaster
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:28,119] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:30,541] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:32,793] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:35,313] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:38,609] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:38,630] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:42,348] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:42,364] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:47,118] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:47,135] TAXII Server Response with different amount of objects! Setting per_request=780
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:50,155] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:50,173] TAXII Server Response with different amount of objects! Setting per_request=187
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:52,957] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-14 11:47:52,972] TAXII Server Response with different amount of objects! Setting per_request=95
# Finalizado 793: ACAD/Medre.A

# %% [markdown]
# **[MITRE] Guardado Software - Técnicas N:N**

# %%
# Filtramos la información que necesitamos
mitre_n2n_techniques_software_df = results_df[['technique_id', 'technique', 'url_technique','software_id','software','software_description','software_type','url_software']]

if save_to_file:
    save_df_as_csv(mitre_n2n_techniques_software_df, '[MITRE]_n2n_techniques_software', 'inter_software_techniques')
# Out:
# Fichero generado correctamente [MITRE]n2n_techniques_software14062024_1340h.csv

# %% [markdown]
# **[CP] Relación Software - Técnicas N:N**

# %%
cp_ttp_available = cp_ttps()
cp_n2n_techniques_software_df = mitre_n2n_techniques_software_df[mitre_n2n_techniques_software_df['technique_id'].isin(cp_ttp_available)]
cp_n2n_techniques_software_df.shape
# Out:
# (8555, 8)

# %%
if save_to_file:
    save_df_as_csv(cp_n2n_techniques_software_df, '[CP]_n2n_techniques_software', 'inter_software_techniques')
# Out:
# Fichero generado correctamente [CP]n2n_techniques_software14062024_1348h.csv

# %% [markdown]
# **[NOCP] Relación Grupos - Técnicas N:N**

# %%
nocp_n2n_techniques_software_df = mitre_n2n_techniques_software_df[~mitre_n2n_techniques_software_df['technique_id'].isin(cp_ttp_available)]
nocp_n2n_techniques_software_df.shape
# Out:
# (522, 8)

# %%
if save_to_file:
    save_df_as_csv(nocp_n2n_techniques_software_df, '[NOCP]_n2n_techniques_software', 'inter_software_techniques')
# Out:
# Fichero generado correctamente [NOCP]n2n_techniques_software14062024_1348h.csv

# %% [markdown]
# #### **4.2 Técnica - Software (1:N)**

# %% [markdown]
# **[MITRE] Técnica - Software (1:N)**

# %%
# Agregamos las columnas por la columna techniques_id
mitre_technique_with_software_df = mitre_n2n_techniques_software_df.groupby('technique_id', as_index=False).agg({
    'technique':unique_list,
    'url_technique':unique_list,
    'software_id': unique_list,
    'software': unique_list,
    'software_description': unique_list,
    'software_type': unique_list,
    'url_software': unique_list
    })
if save_to_file:
    save_df_as_csv(mitre_technique_with_software_df, '[MITRE]_technique_with_software', 'technique_software_1N')

mitre_technique_with_software_df.head(2)
# Out:
# Fichero generado correctamente [MITRE]_technique_with_software14062024_1352h.csv
#   technique_id                        technique  \
# 0        T0800  [Activate Firmware Update Mode]
# 1        T0801          [Monitor Process State]
#
#                                  url_technique            software_id  \
# 0  [https://attack.mitre.org/techniques/T0800]                [S0604]
# 1  [https://attack.mitre.org/techniques/T0801]  [S0604, S0603, S1072]
#
#                                software  \
# 0                         [Industroyer]
# 1  [Industroyer, Industroyer2, Stuxnet]
#
#                                 software_description software_type  \
# 0  [[Industroyer](https://attack.mitre.org/softwa...     [malware]
# 1  [[Stuxnet](https://attack.mitre.org/software/S...     [malware]
#
#                                         url_software
# 0          [https://attack.mitre.org/software/S0604]
# 1  [https://attack.mitre.org/software/S0604, http...

# %%
print(f"[MITRE] Filas del df: {mitre_technique_with_software_df.shape[0]}. Técnicas únicas: {mitre_technique_with_software_df['technique_id'].nunique()}.")
# Out:
# [MITRE] Filas del df: 489. Técnicas únicas: 489.

# %% [markdown]
# **[CP] Técnica - Software (1:N)**

# %%
# Agregamos las columnas por la columna techniques_id
cp_technique_with_software_df = cp_n2n_techniques_software_df.groupby('technique_id', as_index=False).agg({
    'technique':unique_list,
    'url_technique':unique_list,
    'software_id': unique_list,
    'software': unique_list,
    'software_description': unique_list,
    'software_type': unique_list,
    'url_software': unique_list
    })
if save_to_file:
    save_df_as_csv(cp_technique_with_software_df, '[CP]_technique_with_software', 'technique_software_1N')

cp_technique_with_software_df.head(2)
# Out:
# Fichero generado correctamente [CP]_technique_with_software14062024_1356h.csv
#   technique_id                 technique  \
# 0        T0802    [Automated Collection]
# 1        T0807  [Command-Line Interface]
#
#                                  url_technique            software_id  \
# 0  [https://attack.mitre.org/techniques/T0802]  [S0604, S1072, S0093]
# 1  [https://attack.mitre.org/techniques/T0807]         [S0604, S0603]
#
#                                        software  \
# 0  [Backdoor.Oldrea, Industroyer, Industroyer2]
# 1                        [Industroyer, Stuxnet]
#
#                                 software_description software_type  \
# 0  [[Backdoor.Oldrea](https://attack.mitre.org/so...     [malware]
# 1  [[Industroyer](https://attack.mitre.org/softwa...     [malware]
#
#                                         url_software
# 0  [https://attack.mitre.org/software/S0604, http...
# 1  [https://attack.mitre.org/software/S0604, http...

# %%
print(f"[CP] Filas del df: {cp_technique_with_software_df.shape[0]}. TTP's únicas: {cp_technique_with_software_df['technique_id'].nunique()}.")
# Out:
# [CP] Filas del df: 412. TTP's únicas: 412.

# %% [markdown]
# **[NOCP] Técnica - Software (1:N)**

# %%
# Agregamos las columnas por la columna techniques_id
nocp_technique_with_software_df = nocp_n2n_techniques_software_df.groupby('technique_id', as_index=False).agg({
    'technique':unique_list,
    'url_technique':unique_list,
    'software_id': unique_list,
    'software': unique_list,
    'software_description': unique_list,
    'software_type': unique_list,
    'url_software': unique_list
    })
if save_to_file:
    save_df_as_csv(nocp_technique_with_software_df, '[NOCP]_technique_with_software', 'technique_software_1N')

nocp_technique_with_software_df.head(2)
# Out:
# Fichero generado correctamente [NOCP]_technique_with_software14062024_1358h.csv
#   technique_id                        technique  \
# 0        T0800  [Activate Firmware Update Mode]
# 1        T0801          [Monitor Process State]
#
#                                  url_technique            software_id  \
# 0  [https://attack.mitre.org/techniques/T0800]                [S0604]
# 1  [https://attack.mitre.org/techniques/T0801]  [S0604, S0603, S1072]
#
#                                software  \
# 0                         [Industroyer]
# 1  [Industroyer, Industroyer2, Stuxnet]
#
#                                 software_description software_type  \
# 0  [[Industroyer](https://attack.mitre.org/softwa...     [malware]
# 1  [[Stuxnet](https://attack.mitre.org/software/S...     [malware]
#
#                                         url_software
# 0          [https://attack.mitre.org/software/S0604]
# 1  [https://attack.mitre.org/software/S0604, http...

# %%
print(f"[NOCP] Filas del df: {nocp_technique_with_software_df.shape[0]}. TTP's únicas: {nocp_technique_with_software_df['technique_id'].nunique()}.")
# Out:
# [NOCP] Filas del df: 77. TTP's únicas: 77.

# %% [markdown]
# #### **4.3 Software - Técnicas (1:N)**

# %% [markdown]
# **[MITRE] Software - Técnicas (1:N)**

# %%
mitre_software_with_techniques_df = mitre_n2n_techniques_software_df.groupby('software_id', as_index=False).agg({
    'software': unique_list,
    'software_description': unique_list,
    'software_type': unique_list,
    'url_software': unique_list,
    'technique_id':unique_list,
    'technique': unique_list,
    'url_technique':unique_list
    })

if save_to_file:
    save_df_as_csv(mitre_software_with_techniques_df, '[MITRE]_software_with_techniques', 'software_techniques_1N')

mitre_software_with_techniques_df.head(2)
# Out:
# Fichero generado correctamente [MITRE]_software_with_techniques14062024_1402h.csv
#   software_id          software  \
# 0       S0001  [Trojan.Mebromi]
# 1       S0002        [Mimikatz]
#
#                                 software_description software_type  \
# 0  [[Trojan.Mebromi](https://attack.mitre.org/sof...     [malware]
# 1  [[Mimikatz](https://attack.mitre.org/software/...        [tool]
#
#                                 url_software  \
# 0  [https://attack.mitre.org/software/S0001]
# 1  [https://attack.mitre.org/software/S0002]
#
#                                         technique_id  \
# 0                                        [T1542.001]
# 1  [T1649, T1003.006, T1558.001, T1003.002, T1552...
#
#                                            technique  \
# 0                                  [System Firmware]
# 1  [Security Account Manager, Pass the Hash, SID-...
#
#                                        url_technique
# 0    [https://attack.mitre.org/techniques/T1542/001]
# 1  [https://attack.mitre.org/techniques/T1134/005...

# %%
print(f"[MITRE] Filas del df: {mitre_software_with_techniques_df.shape[0]}. Software únicos: {mitre_software_with_techniques_df['software_id'].nunique()}.")
# Out:
# [MITRE] Filas del df: 677. Software únicos: 677.

# %% [markdown]
# **[CP] Software - Técnicas (1:N)**

# %%
cp_software_with_techniques_df = cp_n2n_techniques_software_df.groupby('software_id', as_index=False).agg({
    'software': unique_list,
    'software_description': unique_list,
    'software_type': unique_list,
    'url_software': unique_list,
    'technique_id':unique_list,
    'technique': unique_list,
    'url_technique':unique_list
    })

if save_to_file:
    save_df_as_csv(cp_software_with_techniques_df, '[CP]_software_with_techniques', 'software_techniques_1N')

cp_software_with_techniques_df.head(2)
# Out:
# Fichero generado correctamente [CP]_software_with_techniques14062024_1403h.csv
#   software_id          software  \
# 0       S0001  [Trojan.Mebromi]
# 1       S0002        [Mimikatz]
#
#                                 software_description software_type  \
# 0  [[Trojan.Mebromi](https://attack.mitre.org/sof...     [malware]
# 1  [[Mimikatz](https://attack.mitre.org/software/...        [tool]
#
#                                 url_software  \
# 0  [https://attack.mitre.org/software/S0001]
# 1  [https://attack.mitre.org/software/S0002]
#
#                                         technique_id  \
# 0                                        [T1542.001]
# 1  [T1649, T1003.006, T1558.001, T1003.002, T1552...
#
#                                            technique  \
# 0                                  [System Firmware]
# 1  [Security Account Manager, Pass the Hash, SID-...
#
#                                        url_technique
# 0    [https://attack.mitre.org/techniques/T1542/001]
# 1  [https://attack.mitre.org/techniques/T1134/005...

# %%
print(f"[CP] Filas del df: {cp_software_with_techniques_df.shape[0]}. Software únicos: {cp_software_with_techniques_df['software_id'].nunique()}.")
# Out:
# [CP] Filas del df: 674. Software únicos: 674.

# %% [markdown]
# **[NOCP] Software - Técnicas (1:N)**

# %%
nocp_software_with_techniques_df = nocp_n2n_techniques_software_df.groupby('software_id', as_index=False).agg({
    'software': unique_list,
    'software_description': unique_list,
    'software_type': unique_list,
    'url_software': unique_list,
    'technique_id':unique_list,
    'technique': unique_list,
    'url_technique':unique_list
    })

if save_to_file:
    save_df_as_csv(nocp_software_with_techniques_df, '[NOCP]_software_with_techniques', 'software_techniques_1N')

nocp_software_with_techniques_df.head(2)
# Out:
# Fichero generado correctamente [NOCP]_software_with_techniques_14062024_1405h.csv
#   software_id   software                               software_description  \
# 0       S0003  [RIPTIDE]  [[RIPTIDE](https://attack.mitre.org/software/S...
# 1       S0009    [Hikit]  [[Hikit](https://attack.mitre.org/software/S00...
#
#   software_type                               url_software technique_id  \
# 0     [malware]  [https://attack.mitre.org/software/S0003]  [T1573.001]
# 1     [malware]  [https://attack.mitre.org/software/S0009]  [T1573.001]
#
#                   technique                                    url_technique
# 0  [Symmetric Cryptography]  [https://attack.mitre.org/techniques/T1573/001]
# 1  [Symmetric Cryptography]  [https://attack.mitre.org/techniques/T1573/001]

# %%
print(f"[NOCP] Filas del df: {nocp_software_with_techniques_df.shape[0]}. Software únicos: {nocp_software_with_techniques_df['software_id'].nunique()}.")
# Out:
# [NOCP] Filas del df: 323. Software únicos: 323.

# %% [markdown]
# ### **5. GRUPOS - SOFTWARE**

# %% [markdown]
# #### **5.1 Tablas intermedias (N:N)**

# %%
# Creamos un dataframe vacío con los campos a rellenar
results_df = pd.DataFrame(columns=['type', 'id', 'url', 'matrix', 'created', 'modified', 'created_by_ref',
       'modified_by_ref', 'external_references', 'object_marking_refs',
       'mitre_version', 'mitre_attack_spec_version', 'mitre_deprecated',
       'software', 'software_id', 'software_description', 'software_labels',
       'software_aliases', 'software_platform', 'old_software_id',
       'contributors', 'group_id', 'group', 'group_description',
       'group_aliases', 'url_group'])

# %%
# En este bucle vamos a ir recorriendo cada uno de los grupo y retornando todas los sotfware utilizados por estos. Iremos uniendo toda la información en el df anteriormente creado vacío.
for row in range(row, len(get_groups_df)):
    temp_software_by_group = lift.get_software_used_by_group(get_groups_df.iloc[row], stix_format=False)
    temp_software_by_group_df = pd.json_normalize(temp_software_by_group)

    temp_software_by_group_df['group_id'] = get_groups_df.iloc[row].group_id
    temp_software_by_group_df['group'] = get_groups_df.iloc[row].group
    temp_software_by_group_df['group_description'] = get_groups_df.iloc[row].group_description

    aliases = get_groups_df.iloc[row].group_aliases
    temp_software_by_group_df['group_aliases'] = [aliases] * len(temp_software_by_group_df)

    domains = get_groups_df.iloc[row].matrix
    temp_software_by_group_df['matrix'] = [domains] * len(temp_software_by_group_df)

    temp_software_by_group_df['url_group'] = get_groups_df.iloc[row].url
    temp_software_by_group_df['type'] = get_groups_df.iloc[row].type

    results_df = pd.concat([results_df, temp_software_by_group_df])

    print(f"Finalizado {row}: {get_groups_df.iloc[row].group}")

# Eliminamos duplicados, no debería darse ninguno pero en caso de ejecutar por lotes (cuando se pierde la conexión) es posible que por error humano dupliquemos alguna fila
results_df = results_df.drop_duplicates(subset=['group_id', 'software_id'], keep='last')
# Renombramos la columna url
results_df = results_df.rename(columns={'url': 'url_software'})
# Out:
# [taxii2client.v20] [WARNING ] [2024-06-17 10:31:15,596] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:31:21,134] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:31:27,973] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:31:33,628] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:31:40,517] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:31:40,533] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:31:46,021] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:31:46,038] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:31:50,538] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:31:50,539] TAXII Server Response with different amount of objects! Setting per_request=3
# Finalizado 61: PLATINUM
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:08,704] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:10,958] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:17,429] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:21,600] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:24,453] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:24,469] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:27,839] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:27,858] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:30,057] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:30,057] TAXII Server Response with different amount of objects! Setting per_request=10
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:39,032] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:39,032] TAXII Server Response with different amount of objects! Setting per_request=5
# Finalizado 62: MuddyWater
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:47,135] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:50,105] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:53,694] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:56,044] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:59,848] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:32:59,872] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:03,539] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:03,555] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:06,073] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:06,073] TAXII Server Response with different amount of objects! Setting per_request=3
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:09,058] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:09,058] TAXII Server Response with different amount of objects! Setting per_request=2
# Finalizado 63: Dark Caracal
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:19,915] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:26,454] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:29,374] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:34,579] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:38,034] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:38,047] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:43,901] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:43,902] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:46,020] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:46,020] TAXII Server Response with different amount of objects! Setting per_request=8
# Finalizado 64: Orangeworm
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:57,007] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:33:58,530] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:00,132] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:01,298] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:05,352] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:05,372] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:09,055] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:09,072] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:12,191] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:12,191] TAXII Server Response with different amount of objects! Setting per_request=2
# Finalizado 65: APT19
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:20,613] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:22,166] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:24,785] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:26,637] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:29,523] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:29,539] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:33,042] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:33,058] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:35,260] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:35,260] TAXII Server Response with different amount of objects! Setting per_request=4
# Finalizado 66: Rancor
# [taxii2client.v20] [WARNING ] [2024-06-17 10:34:51,407] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:35:00,715] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:35:03,820] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:35:06,102] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:35:10,656] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:35:10,685] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:35:19,712] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:35:19,717] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:35:24,785] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:35:24,785] TAXII Server Response with different amount of objects! Setting per_request=3
# Finalizado 67: Thrip
# [taxii2client.v20] [WARNING ] [2024-06-17 10:35:45,701] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:35:53,291] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:36:06,252] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:36:16,527] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:36:23,032] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:36:23,052] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:36:31,039] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:36:31,059] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:36:35,692] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:36:35,693] TAXII Server Response with different amount of objects! Setting per_request=4
# Finalizado 68: Leafminer
# [taxii2client.v20] [WARNING ] [2024-06-17 10:36:48,887] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:36:54,659] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:37:01,395] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:37:16,559] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:37:24,766] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:37:24,783] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:37:35,130] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:37:35,141] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:37:44,766] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:37:44,766] TAXII Server Response with different amount of objects! Setting per_request=4
# Finalizado 69: Gorgon Group
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:03,781] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:09,169] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:15,486] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:17,126] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:21,863] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:21,881] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:25,566] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:25,566] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:27,751] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:27,751] TAXII Server Response with different amount of objects! Setting per_request=3
# Finalizado 70: DarkHydrus
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:39,878] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:42,197] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:50,470] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:53,956] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:58,894] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:38:58,910] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:39:07,467] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:39:07,484] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:39:12,221] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:39:12,221] TAXII Server Response with different amount of objects! Setting per_request=6
# Finalizado 71: Cobalt Group
# [taxii2client.v20] [WARNING ] [2024-06-17 10:39:27,801] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:39:30,520] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:39:45,432] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:39:52,588] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:39:58,223] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:39:58,243] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:40:05,532] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:40:05,667] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:40:09,154] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:40:09,155] TAXII Server Response with different amount of objects! Setting per_request=6
# Finalizado 72: Tropic Trooper
# [taxii2client.v20] [WARNING ] [2024-06-17 10:40:24,331] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:40:34,376] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:40:37,778] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:40:47,416] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:40:59,710] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:40:59,731] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:07,286] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:07,286] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:10,669] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:10,670] TAXII Server Response with different amount of objects! Setting per_request=6
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:16,657] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:16,657] TAXII Server Response with different amount of objects! Setting per_request=1
# Finalizado 73: APT38
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:21,978] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:24,497] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:27,783] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:30,085] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:34,171] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:34,188] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:37,845] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:37,858] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:41,044] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:41:41,044] TAXII Server Response with different amount of objects! Setting per_request=5
# Finalizado 74: SilverTerrier
# [taxii2client.v20] [WARNING ] [2024-06-17 10:42:04,329] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:42:16,282] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:42:20,659] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:42:23,179] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:42:27,165] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:42:27,182] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:42:31,985] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:42:32,002] TAXII Server Response with different amount of objects! Setting per_request=1350
# Finalizado 75: Gallmaker
# [taxii2client.v20] [WARNING ] [2024-06-17 10:42:43,061] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:42:50,138] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:03,111] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:09,683] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:14,237] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:14,253] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:18,490] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:18,490] TAXII Server Response with different amount of objects! Setting per_request=1350
# Finalizado 76: FIN4
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:24,312] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:27,664] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:31,701] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:34,270] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:38,457] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:38,483] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:42,527] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:42,543] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:44,812] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:44,813] TAXII Server Response with different amount of objects! Setting per_request=10
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:56,755] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:43:56,755] TAXII Server Response with different amount of objects! Setting per_request=1
# Finalizado 77: APT39
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:05,562] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:07,280] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:08,602] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:10,238] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:13,486] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:13,502] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:17,127] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:17,142] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:20,787] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:20,787] TAXII Server Response with different amount of objects! Setting per_request=2
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:27,097] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:27,097] TAXII Server Response with different amount of objects! Setting per_request=1
# Finalizado 78: TEMP.Veles
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:35,087] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:40,528] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:42,309] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:46,096] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:49,914] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:49,915] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:53,368] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:53,388] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:55,504] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:44:55,505] TAXII Server Response with different amount of objects! Setting per_request=2
# Finalizado 79: The White Company
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:05,913] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:07,997] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:10,086] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:13,468] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:16,504] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:16,524] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:19,509] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:19,509] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:21,844] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:21,844] TAXII Server Response with different amount of objects! Setting per_request=3
# Finalizado 80: WIRTE
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:30,399] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:32,501] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:34,805] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:43,076] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:47,817] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:47,830] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:56,453] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:56,453] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:58,672] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:45:58,672] TAXII Server Response with different amount of objects! Setting per_request=3
# Finalizado 81: Silence
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:11,469] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:14,184] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:17,838] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:20,682] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:26,648] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:26,662] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:31,735] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:31,747] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:37,003] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:37,003] TAXII Server Response with different amount of objects! Setting per_request=10
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:44,260] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:46:44,260] TAXII Server Response with different amount of objects! Setting per_request=6
# Finalizado 82: TA505
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:05,927] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:16,489] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:28,429] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:31,949] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:36,102] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:36,122] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:39,656] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:39,671] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:42,074] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:42,074] TAXII Server Response with different amount of objects! Setting per_request=10
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:50,848] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:47:50,848] TAXII Server Response with different amount of objects! Setting per_request=6
# Finalizado 83: GALLIUM
# [taxii2client.v20] [WARNING ] [2024-06-17 10:48:06,944] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:48:18,047] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:48:31,326] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:48:37,920] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:48:44,058] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:48:44,075] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:48:49,229] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:48:49,246] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:48:51,898] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:48:51,898] TAXII Server Response with different amount of objects! Setting per_request=10
# Finalizado 84: Kimsuky
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:00,971] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:04,159] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:08,201] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:13,966] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:16,903] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:16,918] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:19,988] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:20,004] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:22,425] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:22,425] TAXII Server Response with different amount of objects! Setting per_request=1
# Finalizado 85: Machete
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:30,946] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:32,681] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:34,599] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:35,483] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:38,619] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:38,647] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:41,439] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:41,462] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:43,893] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:43,893] TAXII Server Response with different amount of objects! Setting per_request=10
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:51,197] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:51,197] TAXII Server Response with different amount of objects! Setting per_request=10
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:58,422] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:49:58,422] TAXII Server Response with different amount of objects! Setting per_request=7
# Finalizado 86: APT41
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:07,943] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:10,629] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:12,781] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:14,485] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:17,283] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:17,299] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:20,568] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:20,571] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:24,675] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:24,675] TAXII Server Response with different amount of objects! Setting per_request=1
# Finalizado 87: Bouncing Golf
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:31,996] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:33,448] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:35,785] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:36,853] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:43,476] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:43,489] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:49,504] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:49,514] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:51,747] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:50:51,747] TAXII Server Response with different amount of objects! Setting per_request=6
# Finalizado 88: BlackTech
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:07,459] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:14,964] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:17,817] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:23,339] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:28,707] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:28,710] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:32,630] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:32,646] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:35,668] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:35,668] TAXII Server Response with different amount of objects! Setting per_request=1
# Finalizado 89: APT-C-36
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:46,608] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:51:52,363] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:04,890] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:11,929] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:15,649] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:15,666] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:18,463] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:18,471] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:20,770] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:20,770] TAXII Server Response with different amount of objects! Setting per_request=3
# Finalizado 90: Inception
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:31,845] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:33,363] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:35,031] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:36,701] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:40,069] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:40,088] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:43,555] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:43,565] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:45,774] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:45,774] TAXII Server Response with different amount of objects! Setting per_request=10
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:52,812] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:52,812] TAXII Server Response with different amount of objects! Setting per_request=10
# [taxii2client.v20] [WARNING ] [2024-06-17 10:52:57,653] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# ...
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:00,002] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:00,020] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:03,174] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:03,185] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:05,411] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:05,412] TAXII Server Response with different amount of objects! Setting per_request=9
# Finalizado 141: TA2541
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:15,676] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:21,139] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:25,854] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:33,206] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:42,113] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:42,128] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:50,104] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:50,115] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:54,724] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:35:54,725] TAXII Server Response with different amount of objects! Setting per_request=3
# Finalizado 142: MoustachedBouncer
# [taxii2client.v20] [WARNING ] [2024-06-17 11:36:23,040] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:36:37,062] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:36:41,079] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:36:48,151] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:36:59,117] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:36:59,133] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 11:37:04,374] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:37:04,385] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 11:37:07,842] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:37:07,843] TAXII Server Response with different amount of objects! Setting per_request=2
# Finalizado 143: Mustard Tempest
# [taxii2client.v20] [WARNING ] [2024-06-17 11:37:17,150] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:37:20,447] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:37:35,604] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:37:46,166] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:37:56,388] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:37:56,402] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:03,232] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:03,243] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:08,373] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:08,374] TAXII Server Response with different amount of objects! Setting per_request=8
# Finalizado 144: Cinnamon Tempest
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:25,446] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:29,182] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:33,205] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:38,949] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:45,958] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:45,974] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:50,899] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:50,900] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:53,932] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:38:53,932] TAXII Server Response with different amount of objects! Setting per_request=9
# Finalizado 145: ToddyCat
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:05,490] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:07,571] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:10,528] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:13,551] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:16,720] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:16,736] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:21,862] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:21,873] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:27,769] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:27,770] TAXII Server Response with different amount of objects! Setting per_request=10
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:33,912] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:33,913] TAXII Server Response with different amount of objects! Setting per_request=3
# Finalizado 146: APT5
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:45,124] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:47,358] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:52,937] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:39:56,811] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:00,182] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:00,197] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:03,591] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:03,603] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:06,356] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:06,357] TAXII Server Response with different amount of objects! Setting per_request=6
# Finalizado 147: Akira
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:15,050] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:16,800] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:19,427] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:20,397] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:25,645] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:25,661] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:28,804] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:28,815] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:30,961] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:30,962] TAXII Server Response with different amount of objects! Setting per_request=1
# Finalizado 148: Malteiro
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:51,762] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:40:55,796] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:01,976] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:06,495] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:10,645] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:10,661] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:13,619] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:13,630] TAXII Server Response with different amount of objects! Setting per_request=1350
# Finalizado 149: CyberAv3ngers
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:17,775] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:21,326] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:29,490] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:36,677] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:46,102] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:46,116] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:54,561] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:54,571] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:57,691] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:41:57,693] TAXII Server Response with different amount of objects! Setting per_request=1
# [taxii2client.v20] [WARNING ] [2024-06-17 11:42:02,101] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:42:02,102] TAXII Server Response with different amount of objects! Setting per_request=3
# Finalizado 150: APT-C-23
# [taxii2client.v20] [WARNING ] [2024-06-17 11:42:10,550] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:42:22,772] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:42:35,639] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:42:48,373] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:42:58,292] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:42:58,311] TAXII Server Response with different amount of objects! Setting per_request=1644
# [taxii2client.v20] [WARNING ] [2024-06-17 11:43:05,726] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:43:05,738] TAXII Server Response with different amount of objects! Setting per_request=1350
# [taxii2client.v20] [WARNING ] [2024-06-17 11:43:12,030] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2024-06-17 11:43:12,031] TAXII Server Response with different amount of objects! Setting per_request=1
# Finalizado 151: UNC788

# %% [markdown]
# **[MITRE] Guardado Grupos - Software N:N**
#
# Nota: En este caso no disponemos de un filtro que aplique sobre ninguno de las dos categorías directamente por lo que solo generaremos outputs MITRE.

# %%
n2n_groups_software_df = results_df[['group_id', 'group', 'group_aliases', 'url_group', 'software_id', 'software', 'software_aliases', 'url_software']]
print(f"[MITRE] Filas del df: {n2n_groups_software_df.shape[0]}. Software únicos: {n2n_groups_software_df['software_id'].nunique()}. Grupos únicos: {n2n_groups_software_df['group_id'].nunique()}.")
# Out:
# [MITRE] Filas del df: 932. Software únicos: 509. Grupos únicos: 138.

# %%
# Guardamos la relación entre grupos y software completa:
if save_to_file:
    save_df_as_csv(n2n_groups_software_df, '[MITRE]_n2n_groups_software', 'inter_groups_software')
# Out:
# Fichero generado correctamente [MITRE]_n2n_groups_software_17062024_1422h.csv

# %%
n2n_enterprise_groups_software_df = results_df[['group_id', 'group', 'group_aliases', 'url_group', 'software_id', 'software', 'software_aliases', 'url_software', 'matrix']]
n2n_enterprise_groups_software_df = n2n_enterprise_groups_software_df[n2n_enterprise_groups_software_df['matrix'].apply(lambda x: 'enterprise-attack' in x)]
n2n_enterprise_groups_software_df.drop('matrix', axis=1, inplace=True)
if save_to_file:
    save_df_as_csv(n2n_enterprise_groups_software_df, '[MITRE]_n2n_enterprise_groups_software', 'inter_groups_software')
# Out:
# Fichero generado correctamente [MITRE]_n2n_enterprise_groups_software_17062024_1422h.csv

# %% [markdown]
# #### **5.2 Grupo - Software (1:N)**

# %%
# Agregamos las columnas por la columna group_id
mitre_groups_with_software_df = n2n_groups_software_df.groupby('group_id', as_index=False).agg({
    'group':unique_list,
    'group_aliases': unique_list,
    'url_group': unique_list,
    'software_id': unique_list,
    'software': unique_list,
    'software_aliases': unique_list,
    'url_software': unique_list
    })
if save_to_file:
    save_df_as_csv(mitre_groups_with_software_df, '[MITRE]_groups_with_software', 'group_software_1N')

mitre_groups_with_software_df.head(2)
# Out:
# Fichero generado correctamente [MITRE]_groups_with_software_17062024_1422h.csv
#   group_id     group        group_aliases  \
# 0    G0001   [Axiom]  [(Axiom, Group 72)]
# 1    G0002  [Moafee]          [(Moafee,)]
#
#                                  url_group  \
# 0  [https://attack.mitre.org/groups/G0001]
# 1  [https://attack.mitre.org/groups/G0002]
#
#                                          software_id  \
# 0  [S0009, S0412, S0203, S0012, S0021, S0013, S06...
# 1                                            [S0012]
#
#                                             software  \
# 0  [gh0st RAT, Hydraq, Zox, ZxShell, Hikit, Derus...
# 1                                        [PoisonIvy]
#
#                                     software_aliases  \
# 0  [(Derusbi, PHOTO), (Zox, Gresim, ZoxRPC, ZoxPN...
# 1         [(PoisonIvy, Breut, Poison Ivy, Darkmoon)]
#
#                                         url_software
# 0  [https://attack.mitre.org/software/S0412, http...
# 1          [https://attack.mitre.org/software/S0012]

# %%
# Agregamos las columnas por la columna group_id
mitre_enterprise_groups_with_software_df = n2n_enterprise_groups_software_df.groupby('group_id', as_index=False).agg({
    'group':unique_list,
    'group_aliases': unique_list,
    'url_group': unique_list,
    'software_id': unique_list,
    'software': unique_list,
    'software_aliases': unique_list,
    'url_software': unique_list
    })
if save_to_file:
    save_df_as_csv(mitre_enterprise_groups_with_software_df, '[MITRE]_enterprise_groups_with_software', 'group_software_1N')

mitre_enterprise_groups_with_software_df.head(2)
# Out:
# Fichero generado correctamente [MITRE]_enterprise_groups_with_software_17062024_1422h.csv
#   group_id     group        group_aliases  \
# 0    G0001   [Axiom]  [(Axiom, Group 72)]
# 1    G0002  [Moafee]          [(Moafee,)]
#
#                                  url_group  \
# 0  [https://attack.mitre.org/groups/G0001]
# 1  [https://attack.mitre.org/groups/G0002]
#
#                                          software_id  \
# 0  [S0009, S0412, S0203, S0012, S0021, S0013, S06...
# 1                                            [S0012]
#
#                                             software  \
# 0  [gh0st RAT, Hydraq, Zox, ZxShell, Hikit, Derus...
# 1                                        [PoisonIvy]
#
#                                     software_aliases  \
# 0  [(Derusbi, PHOTO), (Zox, Gresim, ZoxRPC, ZoxPN...
# 1         [(PoisonIvy, Breut, Poison Ivy, Darkmoon)]
#
#                                         url_software
# 0  [https://attack.mitre.org/software/S0412, http...
# 1          [https://attack.mitre.org/software/S0012]

# %% [markdown]
# #### **5.3 Software - Grupo (1:N)**

# %%
# Agregamos las columnas por la columna group_id
mitre_software_with_groups_df = n2n_groups_software_df.groupby('software_id', as_index=False).agg({
    'software': unique_list,
    'software_aliases': unique_list,
    'url_software': unique_list,
    'group_id': unique_list,
    'group':unique_list,
    'group_aliases': unique_list,
    'url_group': unique_list
    })
if save_to_file:
    save_df_as_csv(mitre_software_with_groups_df, '[MITRE]_software_with_groups', 'software_groups_1N')

mitre_software_with_groups_df.head(2)
# Out:
# Fichero generado correctamente [MITRE]_software_with_groups_17062024_1422h.csv
#   software_id    software software_aliases  \
# 0       S0002  [Mimikatz]    [(Mimikatz,)]
# 1       S0003   [RIPTIDE]     [(RIPTIDE,)]
#
#                                 url_software  \
# 0  [https://attack.mitre.org/software/S0002]
# 1  [https://attack.mitre.org/software/S0003]
#
#                                             group_id  \
# 0  [G0006, G0059, G0049, G1024, G0060, G0045, G00...
# 1                                            [G0005]
#
#                                                group  \
# 0  [GALLIUM, Scattered Spider, APT38, APT41, Tont...
# 1                                            [APT12]
#
#                                        group_aliases  \
# 0  [(Leafminer, Raspite), (Wizard Spider, UNC1878...
# 1  [(APT12, IXESHE, DynCalc, Numbered Panda, DNSC...
#
#                                            url_group
# 0  [https://attack.mitre.org/groups/G0010, https:...
# 1            [https://attack.mitre.org/groups/G0005]

# %%
# Agregamos las columnas por la columna group_id
mitre_enterprise_software_with_groups_df = n2n_enterprise_groups_software_df.groupby('software_id', as_index=False).agg({
    'software': unique_list,
    'software_aliases': unique_list,
    'url_software': unique_list,
    'group_id': unique_list,
    'group':unique_list,
    'group_aliases': unique_list,
    'url_group': unique_list
    })
if save_to_file:
    save_df_as_csv(mitre_enterprise_software_with_groups_df, '[MITRE]_enterprise_software_with_groups', 'software_groups_1N')

mitre_enterprise_software_with_groups_df.head(2)
# Out:
# Fichero generado correctamente [MITRE]_enterprise_software_with_groups_17062024_1423h.csv
#   software_id    software software_aliases  \
# 0       S0002  [Mimikatz]    [(Mimikatz,)]
# 1       S0003   [RIPTIDE]     [(RIPTIDE,)]
#
#                                 url_software  \
# 0  [https://attack.mitre.org/software/S0002]
# 1  [https://attack.mitre.org/software/S0003]
#
#                                             group_id  \
# 0  [G0006, G0059, G0049, G1024, G0060, G0045, G00...
# 1                                            [G0005]
#
#                                                group  \
# 0  [GALLIUM, Scattered Spider, APT38, APT41, Tont...
# 1                                            [APT12]
#
#                                        group_aliases  \
# 0  [(Leafminer, Raspite), (Wizard Spider, UNC1878...
# 1  [(APT12, IXESHE, DynCalc, Numbered Panda, DNSC...
#
#                                            url_group
# 0  [https://attack.mitre.org/groups/G0010, https:...
# 1            [https://attack.mitre.org/groups/G0005]

# %% [markdown]
# ### **6. PLATAFORMAS - TÉCNICAS**

# %% [markdown]
# #### **6.1 Tablas intermedias (N:N)**

# %%
mitre_n2n_enterprise_techniques_platforms_df = get_enterprise_techniques_df[['technique_id', 'technique', 'url', 'platform']]
mitre_n2n_enterprise_techniques_platforms_df = mitre_n2n_enterprise_techniques_platforms_df.rename(columns={'url': 'url_technique'})
mitre_n2n_enterprise_techniques_platforms_df = mitre_n2n_enterprise_techniques_platforms_df.explode('platform')
print(f"Filas del df: {mitre_n2n_enterprise_techniques_platforms_df.shape[0]}. TTP's únicas: {mitre_n2n_enterprise_techniques_platforms_df['technique_id'].nunique()}. Plataformas únicas: {mitre_n2n_enterprise_techniques_platforms_df['platform'].nunique()}")
# Out:
# Filas del df: 1654. TTP's únicas: 637. Plataformas únicas: 11

# %% [markdown]
# **[MITRE] Técnicas - Plataformas (N:N)**

# %%
if save_to_file:
    save_df_as_csv(mitre_n2n_enterprise_techniques_platforms_df, '[MITRE]_n2n_enterprise_techniques_platforms', 'inter_techniques_platforms')
# Out:
# Fichero generado correctamente [MITRE]_n2n_enterprise_techniques_platforms_19062024_1523h.csv

# %% [markdown]
# **[CP] Técnicas - Plataformas (N:N)**

# %%
cp_ttp_available = cp_ttps()
cp_n2n_enterprise_techniques_platforms_df = mitre_n2n_enterprise_techniques_platforms_df[mitre_n2n_enterprise_techniques_platforms_df['technique_id'].isin(cp_ttp_available)]
print(f"Filas del df: {cp_n2n_enterprise_techniques_platforms_df.shape[0]}. TTP's únicas: {cp_n2n_enterprise_techniques_platforms_df['technique_id'].nunique()}. Plataformas únicas: {cp_n2n_enterprise_techniques_platforms_df['platform'].nunique()}")
if save_to_file:
    save_df_as_csv(cp_n2n_enterprise_techniques_platforms_df, '[CP]_n2n_enterprise_techniques_platforms', 'inter_techniques_platforms')
# Out:
# Filas del df: 1424. TTP's únicas: 516. Plataformas únicas: 11
# Fichero generado correctamente [CP]_n2n_enterprise_techniques_platforms_19062024_1523h.csv

# %% [markdown]
# **[NOCP] Técnicas - Plataformas (N:N)**

# %%
nocp_ttp_available = cp_ttps()
nocp_n2n_enterprise_techniques_platforms_df = mitre_n2n_enterprise_techniques_platforms_df[~mitre_n2n_enterprise_techniques_platforms_df['technique_id'].isin(cp_ttp_available)]
print(f"Filas del df: {nocp_n2n_enterprise_techniques_platforms_df.shape[0]}. TTP's únicas: {nocp_n2n_enterprise_techniques_platforms_df['technique_id'].nunique()}. Plataformas únicas: {nocp_n2n_enterprise_techniques_platforms_df['platform'].nunique()}")
if save_to_file:
    save_df_as_csv(nocp_n2n_enterprise_techniques_platforms_df, '[NOCP]_n2n_enterprise_techniques_platforms', 'inter_techniques_platforms')
# Out:
# Filas del df: 230. TTP's únicas: 121. Plataformas únicas: 11
# Fichero generado correctamente [NOCP]_n2n_enterprise_techniques_platforms_19062024_1523h.csv

# %% [markdown]
# #### **6.2 Técnica - Plataformas (1:N)**

# %% [markdown]
# **[MITRE] Técnica - Plataformas (1:N)**

# %%
# Agregamos las columnas por la columna technique_id
mitre_technique_with_platforms_df = mitre_n2n_enterprise_techniques_platforms_df.groupby('technique_id', as_index=False).agg({
    'technique':unique_list,
    'url_technique':unique_list,
    'platform': unique_list
    })

if save_to_file:
    save_df_as_csv(mitre_technique_with_platforms_df, '[MITRE]_enterprise_technique_with_platforms', 'technique_platforms_1N')
# Out:
# Fichero generado correctamente [MITRE]_enterprise_technique_with_platforms_19062024_1523h.csv

# %% [markdown]
# **[CP] Técnica - Plataformas (1:N)**

# %%
# Agregamos las columnas por la columna technique_id
cp_technique_with_platforms_df = cp_n2n_enterprise_techniques_platforms_df.groupby('technique_id', as_index=False).agg({
    'technique':unique_list,
    'url_technique':unique_list,
    'platform': unique_list
    })

if save_to_file:
    save_df_as_csv(cp_technique_with_platforms_df, '[CP]_enterprise_technique_with_platforms', 'technique_platforms_1N')
# Out:
# Fichero generado correctamente [CP]_enterprise_technique_with_platforms_19062024_1523h.csv

# %% [markdown]
# **[NOCP] Técnica - Plataformas (1:N)**

# %%
# Agregamos las columnas por la columna technique_id
nocp_technique_with_platforms_df = nocp_n2n_enterprise_techniques_platforms_df.groupby('technique_id', as_index=False).agg({
    'technique':unique_list,
    'url_technique':unique_list,
    'platform': unique_list
    })

if save_to_file:
    save_df_as_csv(nocp_technique_with_platforms_df, '[NOCP]_enterprise_technique_with_platforms', 'technique_platforms_1N')
# Out:
# Fichero generado correctamente [NOCP]_enterprise_technique_with_platforms_19062024_1523h.csv

# %% [markdown]
# #### **6.3 Plataforma - Técnicas (1:N)**

# %% [markdown]
# **[MITRE] Plataforma - Técnicas (1:N)**

# %%
# Agregamos las columnas por la columna technique_id
mitre_platform_with_techniques_df = mitre_n2n_enterprise_techniques_platforms_df.groupby('platform', as_index=False).agg({
    'technique_id':unique_list,
    'technique':unique_list,
    'url_technique':unique_list
    })

if save_to_file:
    save_df_as_csv(mitre_platform_with_techniques_df, '[MITRE]_enterprise_platform_with_techniques', 'platform_techniques_1N')
# Out:
# Fichero generado correctamente [MITRE]_enterprise_platform_with_techniques_19062024_1523h.csv

# %% [markdown]
# **[CP] Plataforma - Técnicas (1:N)**

# %%
# Agregamos las columnas por la columna technique_id
cp_platform_with_techniques_df = cp_n2n_enterprise_techniques_platforms_df.groupby('platform', as_index=False).agg({
    'technique_id':unique_list,
    'technique':unique_list,
    'url_technique':unique_list
    })

if save_to_file:
    save_df_as_csv(cp_platform_with_techniques_df, '[CP]_enterprise_platform_with_techniques', 'platform_techniques_1N')
# Out:
# Fichero generado correctamente [CP]_enterprise_platform_with_techniques_19062024_1523h.csv

# %% [markdown]
# **[NOCP] Plataforma - Técnicas (1:N)**

# %%
# Agregamos las columnas por la columna technique_id
nocp_platform_with_techniques_df = nocp_n2n_enterprise_techniques_platforms_df.groupby('platform', as_index=False).agg({
    'technique_id':unique_list,
    'technique':unique_list,
    'url_technique':unique_list
    })

if save_to_file:
    save_df_as_csv(nocp_platform_with_techniques_df, '[NOCP]_enterprise_platform_with_techniques', 'platform_techniques_1N')
# Out:
# Fichero generado correctamente [NOCP]_enterprise_platform_with_techniques_19062024_1523h.csv

# %% [markdown]
# ### **BONUS. LISTADO DE REGLAS DE DETECCIÓN POR TÉCNICA (TTP ID)**
#
# **Importante:** Debe haberse ejecutado previamente el codigo de obtención de las reglas de detección y clasificación por TTP

# %%
def get_rules_from_path(path):
    # Listas para almacenar los resultados
    sources = []
    ttps = []
    file_names = []
    file_extension = []

    # Recorremos la path accediendo a cada directorio para poder añadirlo a una lista
    for root, dirs, files in os.walk(path):
        for file in files:
            # Extensión del archivo
            ext = os.path.splitext(file)[1].lower()
            if ext in ['.csv', '.yaml','.yml', '.toml', '.md', '.txt', '.yar']:
                # Última y penúltima subcarpeta
                path_split = root.split(os.sep)
                ttp = path_split[-1]
                source = path_split[-2] if len(path_split) > 1 else ''
                # Añadimos elementos a las listas
                sources.append(source)
                ttps.append(ttp)
                file_names.append(file)
                file_extension.append(ext)

    df = pd.DataFrame({'source': sources, 'TTP': ttps, 'rule': file_names, 'file_extension': file_extension})

    return df

# %%
technique_matrix = '' # Dejamos preparado para el futuro cercano la posibilidad de lectura de tecnicas por matriz
path = os.path.join(os.path.dirname(os.getcwd()), 'download_ttps\saved', technique_matrix)
ttp_rules_df = get_rules_from_path(path)
if save_to_file:
    save_df_as_csv(ttp_rules_df, '[CP]_ttp_rules')

# %% [markdown]
# #### **Excepcional: pedido listado de técnicas, tácticas y reglas de detección**

# %%
ttp_rules_df.head(2)
# Out:
#    source    TTP                   rule file_extension
# 0  atomic  T0000       av_exploiting.md            .md
# 1  atomic  T0000  av_password_dumper.md            .md

# %%
count_ttp_rules_df = ttp_rules_df.groupby('TTP').size().reset_index(name='num_rules')
count_ttp_rules_df['TTP'] = count_ttp_rules_df['TTP'].str.upper()
count_ttp_rules_df.head(2)
# Out:
#      TTP  num_rules
# 0  T0000       2128
# 1  T0802         10

# %% [markdown]
# **MITRE**

# %%
mitre_n2n_techniques_tactics_rules = pd.merge(mitre_n2n_enterprise_techniques_tactics, count_ttp_rules_df, how='left', left_on='technique_id', right_on='TTP')
mitre_n2n_techniques_tactics_rules['num_rules'] = mitre_n2n_techniques_tactics_rules['num_rules'].fillna(0).astype(int)
mitre_n2n_techniques_tactics_rules = mitre_n2n_techniques_tactics_rules[['technique_id', 'technique', 'tactic', 'num_rules']]
mitre_n2n_techniques_tactics_rules = mitre_n2n_techniques_tactics_rules.sort_values(by='num_rules', ascending=False)
save_df_as_csv(mitre_n2n_techniques_tactics_rules, '[MITRE]_techniques_tactics_rules')
# Out:
#        tactic technique_id                           technique  \
# 0  collection    T1074.002                 Remote Data Staging
# 1  collection    T1602.001                     SNMP (MIB Dump)
# 2  collection        T1602  Data from Configuration Repository
#
#                                    url_technique tactic_id  \
# 0  https://attack.mitre.org/techniques/T1074/002    TA0009
# 1  https://attack.mitre.org/techniques/T1602/001    TA0009
# 2      https://attack.mitre.org/techniques/T1602    TA0009
#
#                                   tactic_description  \
# 0  The adversary is trying to gather data of inte...
# 1  The adversary is trying to gather data of inte...
# 2  The adversary is trying to gather data of inte...
#
#                                 url_tactic        TTP  num_rules
# 0  https://attack.mitre.org/tactics/TA0009  T1074.002          2
# 1  https://attack.mitre.org/tactics/TA0009  T1602.001          3
# 2  https://attack.mitre.org/tactics/TA0009      T1602          4

# %% [markdown]
# **CYBERPROOF**

# %%
cp_n2n_techniques_tactics_rules = pd.merge(cp_n2n_enterprise_techniques_tactics, count_ttp_rules_df, how='left', left_on='technique_id', right_on='TTP')
cp_n2n_techniques_tactics_rules['num_rules'] = cp_n2n_techniques_tactics_rules['num_rules'].fillna(0).astype(int)
cp_n2n_techniques_tactics_rules = cp_n2n_techniques_tactics_rules[['technique_id', 'technique', 'tactic', 'num_rules']]
cp_n2n_techniques_tactics_rules = cp_n2n_techniques_tactics_rules.sort_values(by='num_rules', ascending=False)
save_df_as_csv(cp_n2n_techniques_tactics_rules, '[CP]_techniques_tactics_rules')
# Out:
# Fichero generado correctamente [CP]_techniques_tactics_rules_19062024_1735h.csv
